# %% [markdown]
# ###################################################################
# #Script Name    :
# #Description    :
# #Args           :
# #Author         : Nikhil Rao in R, converted to Python by Nor Raymond
# #Email          : nraymond@appen.com
# ###################################################################

# %% [markdown]
# ### Fail Rate Reports for Pilot

# %%
import os
import glob 
import pandas as pd
import numpy as np
import yaml
import warnings
from functools import reduce
warnings.filterwarnings("ignore")

# %%
# Function to load yaml configuration file
def load_config(config_name):
    with open(os.path.join(config_path, config_name), 'r') as file:
        config = yaml.safe_load(file)

    return config

config_path = "conf/base"

try:
    
    # load yaml catalog configuration file
    config = load_config("catalog.yml")

    os.chdir(config["project_path"])
    root_path = os.getcwd()
    
except:
    
    os.chdir('..')
    # load yaml catalog configuration file
    config = load_config("catalog.yml")

    os.chdir(config["project_path"])
    root_path = os.getcwd()
    
# import data_processing module
import src.data.data_processing as data_processing
# import data_processing module
import src.data.data_cleaning as data_cleaning

# %%
def language_selection(languages):

    while True:
        try:
            language_index = int(input("\nPlease select the number of the Language you are assessing: "))
            if language_index < min(languages.index) or language_index > max(languages.index):
                print(f"\nYou must enter numbers between {min(languages.index)} - {max(languages.index)}... Please try again")
                continue
            elif language_index == "":
                print("\nYou must enter any numbers")
                continue
            else:
                print(f"\nYou have selected {language_index} for {languages.iloc[language_index, 0]}")
                language_selected = languages.iloc[language_index, 0]
                break

        except ValueError:
            print(f"\nYou must enter numerical values only... Please try again")
            continue
        else:
            break
            
    return language_selected

# %% [markdown]
# #### Functions for Language Modification - getting the overall time taken

# %%
# function for Language Modification
def get_time_taken(df, language_selected):

    # Filter data based on selected language
    dfr = df[df['Language'] == language_selected]

    # Time Taken by Item
    dfr["Time_Taken_Seconds"] = (dfr['_created_at'] - dfr['_started_at']).dt.seconds

    # Time Taken Overall
    dfr_grouped = dfr.groupby('_worker_id').sum('Time_Taken_Seconds')
    dfr_grouped["Time_Taken_Minutes_Overall"] = dfr_grouped["Time_Taken_Seconds"] / 60
    dfr_grouped = dfr_grouped.reset_index()
    dfr = pd.merge(dfr, dfr_grouped[["Time_Taken_Minutes_Overall", "_worker_id"]], how = 'left', on = '_worker_id')

    return dfr

def get_time_taken_all(language_selected, rc, v1, v2):
    
    df_list = [rc, v1, v2]
    keys = ["rcR", "v1R", "v2R"]
    df_time = {}
    
    for df, key in zip(df_list, keys) :

        dfr = get_time_taken(df, language_selected)
        df_time[key] = dfr

    rcR, v1R, v2R = df_time["rcR"], df_time["v1R"], df_time["v2R"]    
    
    return rcR, v1R, v2R

# %% [markdown]
# #### Functions for calculating Fail Rates

# %% [markdown]
# ### PILOT 3A

# %%
####  ------------------------REPORT 1 : "Near Exact Match" - v1_actual_correct_by_question  ------------------------------------------------------------------
####  ---------------------------------------------------------------------------------------------------------------------------------------------------------

####  ------------------------REPORT 2 : "Close Match" - v2_fail_rates  ---------------------------------------------------------------------------------------
####  ---------------------------------------------------------------------------------------------------------------------------------------------------------

####  ------------------------REPORT 3 : "Reading Comprehension" : rc_question_skill_pass_rate  ---------------------------------------------------------------
####  ---------------------------------------------------------------------------------------------------------------------------------------------------------

####  ------------------------REPORT 4 : "RC with Answers" : rc_question_skill_pass_rate_answer_final  --------------------------------------------------------
####  ---------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
####  ------------------------REPORT 1 : "Near Exact Match" - v1_actual_correct_by_question  ---------------------------------------------------------------

def v1_fail_rate_3A(v1R):  #Valid for 3A
    
    vR_temp = v1R[['Language', 'Fluency', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 
                    'wordphrase_a', 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score']]
    
    # first grouping
    vR_grouped = vR_temp.groupby(['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
    # second grouping
    vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                    'b_domain', 'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and Fail_rate descending 
    vR_grouped = vR_grouped.sort_values(['Fluency', 'Fail_Rate'], ascending=[True, False])
    
    vR_fail_rates = vR_grouped.reset_index(drop=True) #re-order df index
    
    return vR_fail_rates

def generate_report_1_3A(v1R):
    
    v1_actual_correct_by_question = v1_fail_rate_3A(v1R)
    
    return v1_actual_correct_by_question

####  ---------------------------------------------------------------------------------------------------------------------------------------------------------


####  ------------------------REPORT 2 : "Close Match" - v2_fail_rates  ---------------------------------------------------------------------------------------

def v2_fail_rate_3A(v2R):
    
    vR_temp = v2R[['Language', 'Fluency', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                   'b_register', 'wordphrase_b', 'difficulty', 'Answers', 'Score']]
    
    # first grouping
    vR_grouped = vR_temp.groupby(['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                                  'b_register', 'wordphrase_b', 'difficulty', 'Answers', 'Score'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
    # second grouping
    vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                    'b_domain', 'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
    vR_grouped['Overall_Fail_Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', '_unit_id'], ascending = [True, True])
    
    # drop Score column
    vR_grouped = vR_grouped.drop('Score', axis = 1)
    
    vR_fail_rates = vR_grouped.reset_index(drop=True) #re-order df index
    
    return vR_fail_rates

def v2_fail_rate_2_3A(v2R):
    
    vR_temp = v2R[['Language', 'Fluency', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                   'b_register', 'wordphrase_b', 'difficulty', 'rater_answer', 'Answers', 'Score']]
    
    # first grouping
    vR_grouped = vR_temp.groupby(['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                                  'b_register', 'wordphrase_b', 'difficulty', 'rater_answer', 'Answers', 'Score'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
    # second grouping
    vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                                                          'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
    vR_grouped['Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', '_unit_id', 'Score', 'Rate'], ascending = [True, True, True, False])
    
    # drop Score columns
    vR_grouped = vR_grouped.drop(['Score', 'Count_of_Test_Takers', 'Total_Test_Takers'], axis = 1)
    
    vR_fail_rates = vR_grouped.reset_index(drop=True) #re-order df index
    
    vR_fail_rates  = pd.pivot_table(vR_fail_rates, 
                           index=['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                                  'b_register', 'wordphrase_b', 'difficulty', 'Answers'],
                           values='Rate', columns=['rater_answer']).reset_index()
    vR_fail_rates.columns.name = None # remove name for columns
    
    # remove duplicate rows in the dataframe
    vR_fail_rates = vR_fail_rates.drop_duplicates()
    
    return vR_fail_rates 

def merge_v2_fail_rates_3A(v2_actual_correct_by_question, v2_actual_correct_by_question_with_answer):
    
    v2_fail_rates = pd.merge(v2_actual_correct_by_question_with_answer, v2_actual_correct_by_question, how = 'left', 
                            on = ["Language", "Fluency", "_unit_id", "question_", "a_domain", "a_register", "wordphrase_a", "b_domain",
                                  "b_register", "wordphrase_b", "difficulty", "Answers"])
    
#     v2_fail_rates = v2_fail_rates[['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a',
#                 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Count_of_Test_Takers', 'Total_Test_Takers',
#                 'Overall_Fail_Rate', 'Answers', 'a_and_b_are_not_related', 'a_and_b_are_related', 'a_and_b_have_the_same_meaning',
#                 'a_is_more_specific_than_b', 'b_is_more_specific_than_a']]
    
    return v2_fail_rates

def generate_report_2_3A(v2R):
    
    v2_actual_correct_by_question = v2_fail_rate_3A(v2R)

    v2_actual_correct_by_question_with_answer = v2_fail_rate_2_3A(v2R)

    v2_fail_rates = merge_v2_fail_rates_3A(v2_actual_correct_by_question, v2_actual_correct_by_question_with_answer)
    
    return v2_fail_rates


####  ---------------------------------------------------------------------------------------------------------------------------------------------------------


####  ------------------------REPORT 3 : "Reading Comprehension" : rc_question_skill_pass_rate  ---------------------------------------------------------------

def rc_fail_rate_3A(rcR):

    vR_temp = rcR[['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds', '_unit_id', 'title', 'test_',
                'question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested',
                'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                'register', 'topic', 'text_type', 'complexity', 'familiarity', 
                'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
                'Score']]
    
    # evaluate if Answers are the same as the questions. If either Q or A are empty, return NaN
    if vR_temp['question_no_1'].isnull().all() == True or vR_temp['Answer_no_1'].isnull().all() == True:      
        vR_temp['a1'] = np.nan      
    else:   
        vR_temp['a1'] = np.where(vR_temp['question_no_1'] == vR_temp['Answer_no_1'], 1, 0).astype('str')
        
    if vR_temp['question_no_2'].isnull().all() == True or vR_temp['Answer_no_2'].isnull().all() == True:        
        vR_temp['a2'] = np.nan      
    else:       
        vR_temp['a2'] = np.where(vR_temp['question_no_2'] == vR_temp['Answer_no_2'], 1, 0).astype('str')      
        
    if vR_temp['question_no_3'].isnull().all() == True or vR_temp['Answer_no_3'].isnull().all() == True:  
        vR_temp['a3'] = np.nan 
    else:
        vR_temp['a3'] = np.where(vR_temp['question_no_3'] == vR_temp['Answer_no_3'], 1, 0).astype('str')
        
    if vR_temp['question_no_4'].isnull().all() == True or vR_temp['Answer_no_4'].isnull().all() == True:   
        vR_temp['a4'] = np.nan 
    else:
        vR_temp['a4'] = np.where(vR_temp['question_no_4'] == vR_temp['Answer_no_4'], 1, 0).astype('str')
    
    # Dropping columns
    vR_temp = vR_temp.drop(['question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                            'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4', 'Score'], axis =1)  
    
    # concatenate values from different columns with delimiter ;
    vR_temp['Score'] = vR_temp[['a1', 'a2', 'a3', 'a4']].astype('str').agg(';'.join, axis=1) 
    vR_temp['Question'] = ';'.join(['Question 1', 'Question 2', 'Question 3', 'Question 4'])
    vR_temp['Difficulty'] = vR_temp[['question_1_difficulty', 'question_2_difficulty', 
                                     'question_3_difficulty', 'question_4_difficulty']].astype('str').agg(';'.join, axis=1) 
    vR_temp['Google_Translate_Error'] = vR_temp[['question_1_google_translate_error', 
                                                 'question_2_google_translate_error', 
                                                 'question_3_google_translate_error', 
                                                 'question_4_google_translate_error']].astype('str').agg(';'.join, axis=1) 
    vR_temp['Skill'] = vR_temp[['Question 1 Skill tested', 'Question 2 Skill tested', 
                                'Question 3 Skill tested', 'Question 4 Skill tested']].astype('str').agg(';'.join, axis=1) 
    
    # Dropping more columns
    vR_temp = vR_temp.drop(['question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested', 
                            'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                            'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                            'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                            'a1', 'a2', 'a3', 'a4'], axis =1)  
    
    # Python explode function to split delimited columns and expand to rows - row_separate in R
    vR_temp =  vR_temp.set_index(['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds',
       '_unit_id', 'title', 'test_', 'register', 'topic', 'text_type',
       'complexity', 'familiarity']).apply(lambda x: x.str.split(';').explode()).reset_index()
    
    vR_temp[['Score', 'Question', 'Difficulty', 'Google_Translate_Error', 'Skill']] = vR_temp[['Score', 'Question', 'Difficulty', 
                                                                                               'Google_Translate_Error', 'Skill']].replace('nan', np.nan)
    vR_temp = vR_temp.dropna(subset = ['Score'])  # remove rows with NaN values in Score 
    vR_temp['Score'] = vR_temp['Score'].astype('int') # set Score as integer
    
    rc_answer = vR_temp
    
    return vR_temp

## Melt RC and categorize question choice with letter and question number
def melt_rc_assign_3A(rc_choices, q_list, choice_list):
    
    df=[]
    for ql in q_list:
        for cl in choice_list:
            df_temp_1 = rc_choices[rc_choices['variable'].str.contains('question_' + str(ql))]
            df_temp_2 = df_temp_1[df_temp_1['variable'].str.contains('choice_' + str(cl))]
            df_temp_2['Question'] = 'Question ' + str(ql)
            if cl == 1 :
                df_temp_2['Answer'] = 'a'
            elif cl == 2 :
                df_temp_2['Answer'] = 'b'
            elif cl == 3 :
                df_temp_2['Answer'] = 'c'
            df.append(df_temp_2)
            
    rc_choices = pd.concat(df)
    return rc_choices

## Melt RC and categorize question choice with letter and question number
def melt_rc_3A(rcR):

    vR_temp = rcR[['Language', '_unit_id', 'title', 'test_',
                'question_1_choice_1', 'question_1_choice_2', 'question_1_choice_3',
                'question_2_choice_1', 'question_2_choice_2', 'question_2_choice_3',
                'question_3_choice_1', 'question_3_choice_2', 'question_3_choice_3',
                'question_4_choice_1', 'question_4_choice_2', 'question_4_choice_3']]
    
    # remove duplicate rows in the dataframe
    vR_temp = vR_temp.drop_duplicates().reset_index(drop=True)
    
    vR_temp = pd.melt(vR_temp, id_vars=['Language', '_unit_id', 'title', 'test_'])
    
    rc_choices = vR_temp
    
    q_list, choice_list = [1,2,3,4], [1,2,3]
    rc_choices = melt_rc_assign_3A(rc_choices, q_list, choice_list)
    rc_choices = rc_choices[['Language', '_unit_id', 'title', 'test_', 'Question', 'Answer', 'variable', 'value']]
    rc_choices = rc_choices.sort_values(['Language', 'title', 'test_', 'Question', 'Answer'])
    
    actual_answer = rc_choices
    rater_answer = rc_choices
    
    return rc_choices, actual_answer, rater_answer

# ## Melt RC into long format with actual answers
def melt_rc_answer_actual_3A(rcR):
    
    vR_temp = rcR[['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds', '_unit_id', 'title', 'test_',
                'question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested',
                'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                'register', 'topic', 'text_type', 'complexity', 'familiarity',
                'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
                'Score']]
    
    # evaluate if Answers are the same as the questions. If either Q or A are empty, return NaN
    if vR_temp['question_no_1'].isnull().all() == True or vR_temp['Answer_no_1'].isnull().all() == True:      
        vR_temp['a1'] = np.nan      
    else:   
        vR_temp['a1'] = np.where(vR_temp['question_no_1'] == vR_temp['Answer_no_1'], 1, 0).astype('str')
        
    if vR_temp['question_no_2'].isnull().all() == True or vR_temp['Answer_no_2'].isnull().all() == True:        
        vR_temp['a2'] = np.nan      
    else:       
        vR_temp['a2'] = np.where(vR_temp['question_no_2'] == vR_temp['Answer_no_2'], 1, 0).astype('str')      
        
    if vR_temp['question_no_3'].isnull().all() == True or vR_temp['Answer_no_3'].isnull().all() == True:  
        vR_temp['a3'] = np.nan 
    else:
        vR_temp['a3'] = np.where(vR_temp['question_no_3'] == vR_temp['Answer_no_3'], 1, 0).astype('str')
        
    if vR_temp['question_no_4'].isnull().all() == True or vR_temp['Answer_no_4'].isnull().all() == True:   
        vR_temp['a4'] = np.nan 
    else:
        vR_temp['a4'] = np.where(vR_temp['question_no_4'] == vR_temp['Answer_no_4'], 1, 0).astype('str')
    
    vR_temp = vR_temp.drop('Score', axis = 1)
    
    # concatenate values from different columns with delimiter ;
    vR_temp['Score'] = vR_temp[['a1', 'a2', 'a3', 'a4']].astype('str').agg(';'.join, axis=1) 
    vR_temp['Rater_Answer'] = vR_temp[['question_no_1', 'question_no_2', 'question_no_3', 'question_no_4']].astype('str').agg(';'.join, axis=1)
    vR_temp['Actual_Answer'] = vR_temp[['Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4']].astype('str').agg(';'.join, axis=1) 
    vR_temp['Question'] = ';'.join(['Question 1', 'Question 2', 'Question 3', 'Question 4'])
    vR_temp['Difficulty'] = vR_temp[['question_1_difficulty', 'question_2_difficulty', 
                                     'question_3_difficulty', 'question_4_difficulty']].astype('str').agg(';'.join, axis=1) 
    vR_temp['Google_Translate_Error'] = vR_temp[['question_1_google_translate_error', 
                                                 'question_2_google_translate_error', 
                                                 'question_3_google_translate_error', 
                                                 'question_4_google_translate_error']].astype('str').agg(';'.join, axis=1) 
    vR_temp['Skill'] = vR_temp[['Question 1 Skill tested', 'Question 2 Skill tested', 
                                'Question 3 Skill tested', 'Question 4 Skill tested']].astype('str').agg(';'.join, axis=1) 
    
    vR_temp = vR_temp.drop(['question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested', 
                            'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                            'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                            'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                            'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                            'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
                            'a1', 'a2', 'a3', 'a4'], axis = 1)
    
     # Python explode function to split delimited columns and expand to rows - row_separate in R
    vR_temp =  vR_temp.set_index(['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds',
       '_unit_id', 'title', 'test_', 'register', 'topic', 'text_type',
       'complexity', 'familiarity']).apply(lambda x: x.str.split(';').explode()).reset_index()
    
    vR_temp[['Score', 'Rater_Answer', 'Actual_Answer', 'Question', 'Difficulty', 'Google_Translate_Error', 'Skill']] = vR_temp[['Score', 'Rater_Answer', 
                                                                                                                                'Actual_Answer','Question', 
                                                                                                                                'Difficulty', 
                                                                                                                                'Google_Translate_Error', 
                                                                                                                                'Skill']].replace('nan', np.nan)
    vR_temp = vR_temp.dropna(subset = ['Score'])  # remove rows with NaN values in Score 
    vR_temp['Score'] = vR_temp['Score'].astype('int') # set Score as integer
    
    rc_answer_actual = vR_temp
    
    return rc_answer_actual

def rc_q_s_pass_rate_3A(rc_answer):
    
    # first grouping
    vR_grouped = rc_answer.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Score', 'Question', 'Difficulty', 'register', 'Skill'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count"})
    
    # second grouping
    vR_grouped['Total'] = vR_grouped.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Question', 'Difficulty', 'register', 'Skill'])['Count'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count'] / vR_grouped['Total']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', 'Fail_Rate'], ascending = [True, False])
    vR_grouped = vR_grouped.reset_index(drop=True) #re-order df index
    
    rc_question_skill_pass_rate = vR_grouped
    
    return rc_question_skill_pass_rate

def generate_report_3_3A(rcR):
    
    rc_answer = rc_fail_rate_3A(rcR)
    
    rc_choices, actual_answer, rater_answer = melt_rc_3A(rcR)
    
    rc_answer_actual = melt_rc_answer_actual_3A(rcR)
    
    rc_question_skill_pass_rate = rc_q_s_pass_rate_3A(rc_answer)
    
    return rc_question_skill_pass_rate

####  ---------------------------------------------------------------------------------------------------------------------------------------------------------


####  ------------------------REPORT 4 : "RC with Answers" : rc_question_skill_pass_rate_answer_final  --------------------------------------------------------

def rc_q_s_pass_rate_answer_3A(rc_answer_actual):
    
    # first grouping
    vR_grouped = rc_answer_actual.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Actual_Answer', 'Rater_Answer', 
                                    'Score', 'Question', 'Difficulty', 'register', 'Skill'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count"})
    
    # second grouping
    vR_grouped['Total'] = vR_grouped.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Question', 'Difficulty', 'register', 'Skill'])['Count'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count'] / vR_grouped['Total']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', '_unit_id', 'Question', 'Fail_Rate'], ascending = [True, True, True, False])
    vR_grouped = vR_grouped.reset_index(drop=True) #re-order df index
    
    rc_question_skill_pass_rate_answer = vR_grouped
    
    return rc_question_skill_pass_rate_answer

def join_rc_q_s_pass_rate_answer_3A(rc_question_skill_pass_rate_answer, actual_answer, rater_answer):
    
    first_join = rc_question_skill_pass_rate_answer
    first_join = pd.merge(first_join, actual_answer, how = 'left', 
                            left_on = ["Language", "_unit_id", "title" , "test_", "Question", "Actual_Answer"],
                            right_on = ["Language", "_unit_id", "title" , "test_", "Question", "Answer"])
    first_join = first_join.drop('Answer', axis=1)
    
    second_join = pd.merge(first_join, rater_answer, how = 'left', 
                            left_on = ["Language", "_unit_id", "title" , "test_", "Question", "Rater_Answer"],
                            right_on = ["Language", "_unit_id", "title" , "test_", "Question", "Answer"])
    second_join = second_join.drop('Answer', axis=1)
    
    second_join = second_join[['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Difficulty', 'register', 'Skill', 'Question',
                               'Actual_Answer', 'value_x', 'Rater_Answer', 'value_y', 'Count', 'Total', 'Fail_Rate']]
  
    second_join = second_join.rename(columns = { "Actual_Answer" : "Actual_Answer_Letter", 
                                       "value_x" : "Actual_Answer_Text",
                                       "Rater_Answer" : "Rater_Answer_Letter",
                                       "value_y" : "Rater_Answer_Text"})

    rc_question_skill_pass_rate_answer_final = second_join
    
    return rc_question_skill_pass_rate_answer_final


def generate_report_4_3A(rcR):
    
    rc_choices, actual_answer, rater_answer = melt_rc_3A(rcR)
    
    rc_answer_actual = melt_rc_answer_actual_3A(rcR)
    
    rc_question_skill_pass_rate_answer = rc_q_s_pass_rate_answer_3A(rc_answer_actual)

    rc_question_skill_pass_rate_answer_final = join_rc_q_s_pass_rate_answer_3A(rc_question_skill_pass_rate_answer, actual_answer, rater_answer)
    
    return rc_question_skill_pass_rate_answer_final

####  ---------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### REPORT 2 : "Close Match" - v2_fail_rates

# %%
# def v2_fail_rate_3A(v2R):
    
#     vR_temp = v2R[['Language', 'Fluency', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
#                    'b_register', 'wordphrase_b', 'difficulty', 'Answers', 'Score']]
    
#     # first grouping
#     vR_grouped = vR_temp.groupby(['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
#                                   'b_register', 'wordphrase_b', 'difficulty', 'Answers', 'Score'])['_worker_id'].count().reset_index()
#     vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
#     # second grouping
#     vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
#                                     'b_domain', 'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
#     vR_grouped['Overall_Fail_Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
#     # filter Score 0 
#     vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
#     # sort values by Market and _unit_id 
#     vR_grouped = vR_grouped.sort_values(['Fluency', '_unit_id'], ascending = [True, True])
    
#     # drop Score column
#     vR_grouped = vR_grouped.drop('Score', axis = 1)
    
#     vR_fail_rates = vR_grouped.reset_index(drop=True) #re-order df index
    
#     return vR_fail_rates

# def v2_fail_rate_2_3A(v2R):
    
#     vR_temp = v2R[['Language', 'Fluency', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
#                    'b_register', 'wordphrase_b', 'difficulty', 'rater_answer', 'Answers', 'Score']]
    
#     # first grouping
#     vR_grouped = vR_temp.groupby(['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
#                                   'b_register', 'wordphrase_b', 'difficulty', 'rater_answer', 'Answers', 'Score'])['_worker_id'].count().reset_index()
#     vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
#     # second grouping
#     vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
#                                                           'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
#     vR_grouped['Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
#     # filter Score 0 
#     vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
#     # sort values by Market and _unit_id 
#     vR_grouped = vR_grouped.sort_values(['Fluency', '_unit_id', 'Score', 'Rate'], ascending = [True, True, True, False])
    
#     # drop Score columns
#     vR_grouped = vR_grouped.drop(['Score', 'Count_of_Test_Takers', 'Total_Test_Takers'], axis = 1)
    
#     vR_fail_rates = vR_grouped.reset_index(drop=True) #re-order df index
    
#     vR_fail_rates  = pd.pivot_table(vR_fail_rates, 
#                            index=['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
#                                   'b_register', 'wordphrase_b', 'difficulty', 'Answers'],
#                            values='Rate', columns=['rater_answer']).reset_index()
#     vR_fail_rates.columns.name = None # remove name for columns
    
#     # remove duplicate rows in the dataframe
#     vR_fail_rates = vR_fail_rates.drop_duplicates()
    
#     return vR_fail_rates 

# def merge_v2_fail_rates_3A(v2_actual_correct_by_question, v2_actual_correct_by_question_with_answer):
    
#     v2_fail_rates = pd.merge(v2_actual_correct_by_question_with_answer, v2_actual_correct_by_question, how = 'left', 
#                             on = ["Language", "Fluency", "_unit_id", "question_", "a_domain", "a_register", "wordphrase_a", "b_domain",
#                                   "b_register", "wordphrase_b", "difficulty", "Answers"])
    
# #     v2_fail_rates = v2_fail_rates[['Language', 'Fluency', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a',
# #                 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Count_of_Test_Takers', 'Total_Test_Takers',
# #                 'Overall_Fail_Rate', 'Answers', 'a_and_b_are_not_related', 'a_and_b_are_related', 'a_and_b_have_the_same_meaning',
# #                 'a_is_more_specific_than_b', 'b_is_more_specific_than_a']]
    
#     return v2_fail_rates

# def generate_report_2_3A(v2R):
    
#     v2_actual_correct_by_question = v2_fail_rate_3A(v2R)

#     v2_actual_correct_by_question_with_answer = v2_fail_rate_2_3A(v2R)

#     v2_fail_rates = merge_v2_fail_rates_3A(v2_actual_correct_by_question, v2_actual_correct_by_question_with_answer)
    
#     return v2_fail_rates

# %% [markdown]
# #### REPORT 3 : "Reading Comprehension" : rc_question_skill_pass_rate

# %%
# def rc_fail_rate_3A(rcR):

#     vR_temp = rcR[['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds', '_unit_id', 'title', 'test_',
#                 'question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested',
#                 'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
#                 'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
#                 'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
#                 'register', 'topic', 'text_type', 'complexity', 'familiarity', 
#                 'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
#                 'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
#                 'Score']]
    
#     # evaluate if Answers are the same as the questions. If either Q or A are empty, return NaN
#     if vR_temp['question_no_1'].isnull().all() == True or vR_temp['Answer_no_1'].isnull().all() == True:      
#         vR_temp['a1'] = np.nan      
#     else:   
#         vR_temp['a1'] = np.where(vR_temp['question_no_1'] == vR_temp['Answer_no_1'], 1, 0).astype('str')
        
#     if vR_temp['question_no_2'].isnull().all() == True or vR_temp['Answer_no_2'].isnull().all() == True:        
#         vR_temp['a2'] = np.nan      
#     else:       
#         vR_temp['a2'] = np.where(vR_temp['question_no_2'] == vR_temp['Answer_no_2'], 1, 0).astype('str')      
        
#     if vR_temp['question_no_3'].isnull().all() == True or vR_temp['Answer_no_3'].isnull().all() == True:  
#         vR_temp['a3'] = np.nan 
#     else:
#         vR_temp['a3'] = np.where(vR_temp['question_no_3'] == vR_temp['Answer_no_3'], 1, 0).astype('str')
        
#     if vR_temp['question_no_4'].isnull().all() == True or vR_temp['Answer_no_4'].isnull().all() == True:   
#         vR_temp['a4'] = np.nan 
#     else:
#         vR_temp['a4'] = np.where(vR_temp['question_no_4'] == vR_temp['Answer_no_4'], 1, 0).astype('str')
    
#     # Dropping columns
#     vR_temp = vR_temp.drop(['question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
#                             'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4', 'Score'], axis =1)  
    
#     # concatenate values from different columns with delimiter ;
#     vR_temp['Score'] = vR_temp[['a1', 'a2', 'a3', 'a4']].astype('str').agg(';'.join, axis=1) 
#     vR_temp['Question'] = ';'.join(['Question 1', 'Question 2', 'Question 3', 'Question 4'])
#     vR_temp['Difficulty'] = vR_temp[['question_1_difficulty', 'question_2_difficulty', 
#                                      'question_3_difficulty', 'question_4_difficulty']].astype('str').agg(';'.join, axis=1) 
#     vR_temp['Google_Translate_Error'] = vR_temp[['question_1_google_translate_error', 
#                                                  'question_2_google_translate_error', 
#                                                  'question_3_google_translate_error', 
#                                                  'question_4_google_translate_error']].astype('str').agg(';'.join, axis=1) 
#     vR_temp['Skill'] = vR_temp[['Question 1 Skill tested', 'Question 2 Skill tested', 
#                                 'Question 3 Skill tested', 'Question 4 Skill tested']].astype('str').agg(';'.join, axis=1) 
    
#     # Dropping more columns
#     vR_temp = vR_temp.drop(['question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested', 
#                             'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
#                             'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
#                             'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
#                             'a1', 'a2', 'a3', 'a4'], axis =1)  
    
#     # Python explode function to split delimited columns and expand to rows - row_separate in R
#     vR_temp =  vR_temp.set_index(['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds',
#        '_unit_id', 'title', 'test_', 'register', 'topic', 'text_type',
#        'complexity', 'familiarity']).apply(lambda x: x.str.split(';').explode()).reset_index()
    
#     vR_temp[['Score', 'Question', 'Difficulty', 'Google_Translate_Error', 'Skill']] = vR_temp[['Score', 'Question', 'Difficulty', 
#                                                                                                'Google_Translate_Error', 'Skill']].replace('nan', np.nan)
#     vR_temp = vR_temp.dropna(subset = ['Score'])  # remove rows with NaN values in Score 
#     vR_temp['Score'] = vR_temp['Score'].astype('int') # set Score as integer
    
#     rc_answer = vR_temp
    
#     return vR_temp

# ## Melt RC and categorize question choice with letter and question number
# def melt_rc_assign_3A(rc_choices, q_list, choice_list):
    
#     df=[]
#     for ql in q_list:
#         for cl in choice_list:
#             df_temp_1 = rc_choices[rc_choices['variable'].str.contains('question_' + str(ql))]
#             df_temp_2 = df_temp_1[df_temp_1['variable'].str.contains('choice_' + str(cl))]
#             df_temp_2['Question'] = 'Question ' + str(ql)
#             if cl == 1 :
#                 df_temp_2['Answer'] = 'a'
#             elif cl == 2 :
#                 df_temp_2['Answer'] = 'b'
#             elif cl == 3 :
#                 df_temp_2['Answer'] = 'c'
#             df.append(df_temp_2)
            
#     rc_choices = pd.concat(df)
#     return rc_choices

# ## Melt RC and categorize question choice with letter and question number
# def melt_rc_3A(rcR):

#     vR_temp = rcR[['Language', '_unit_id', 'title', 'test_',
#                 'question_1_choice_1', 'question_1_choice_2', 'question_1_choice_3',
#                 'question_2_choice_1', 'question_2_choice_2', 'question_2_choice_3',
#                 'question_3_choice_1', 'question_3_choice_2', 'question_3_choice_3',
#                 'question_4_choice_1', 'question_4_choice_2', 'question_4_choice_3']]
    
#     # remove duplicate rows in the dataframe
#     vR_temp = vR_temp.drop_duplicates().reset_index(drop=True)
    
#     vR_temp = pd.melt(vR_temp, id_vars=['Language', '_unit_id', 'title', 'test_'])
    
#     rc_choices = vR_temp
    
#     q_list, choice_list = [1,2,3,4], [1,2,3]
#     rc_choices = melt_rc_assign_3A(rc_choices, q_list, choice_list)
#     rc_choices = rc_choices[['Language', '_unit_id', 'title', 'test_', 'Question', 'Answer', 'variable', 'value']]
#     rc_choices = rc_choices.sort_values(['Language', 'title', 'test_', 'Question', 'Answer'])
    
#     actual_answer = rc_choices
#     rater_answer = rc_choices
    
#     return rc_choices, actual_answer, rater_answer

# # ## Melt RC into long format with actual answers
# def melt_rc_answer_actual_3A(rcR):
    
#     vR_temp = rcR[['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds', '_unit_id', 'title', 'test_',
#                 'question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested',
#                 'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
#                 'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
#                 'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
#                 'register', 'topic', 'text_type', 'complexity', 'familiarity',
#                 'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
#                 'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
#                 'Score']]
    
#     # evaluate if Answers are the same as the questions. If either Q or A are empty, return NaN
#     if vR_temp['question_no_1'].isnull().all() == True or vR_temp['Answer_no_1'].isnull().all() == True:      
#         vR_temp['a1'] = np.nan      
#     else:   
#         vR_temp['a1'] = np.where(vR_temp['question_no_1'] == vR_temp['Answer_no_1'], 1, 0).astype('str')
        
#     if vR_temp['question_no_2'].isnull().all() == True or vR_temp['Answer_no_2'].isnull().all() == True:        
#         vR_temp['a2'] = np.nan      
#     else:       
#         vR_temp['a2'] = np.where(vR_temp['question_no_2'] == vR_temp['Answer_no_2'], 1, 0).astype('str')      
        
#     if vR_temp['question_no_3'].isnull().all() == True or vR_temp['Answer_no_3'].isnull().all() == True:  
#         vR_temp['a3'] = np.nan 
#     else:
#         vR_temp['a3'] = np.where(vR_temp['question_no_3'] == vR_temp['Answer_no_3'], 1, 0).astype('str')
        
#     if vR_temp['question_no_4'].isnull().all() == True or vR_temp['Answer_no_4'].isnull().all() == True:   
#         vR_temp['a4'] = np.nan 
#     else:
#         vR_temp['a4'] = np.where(vR_temp['question_no_4'] == vR_temp['Answer_no_4'], 1, 0).astype('str')
    
#     vR_temp = vR_temp.drop('Score', axis = 1)
    
#     # concatenate values from different columns with delimiter ;
#     vR_temp['Score'] = vR_temp[['a1', 'a2', 'a3', 'a4']].astype('str').agg(';'.join, axis=1) 
#     vR_temp['Rater_Answer'] = vR_temp[['question_no_1', 'question_no_2', 'question_no_3', 'question_no_4']].astype('str').agg(';'.join, axis=1)
#     vR_temp['Actual_Answer'] = vR_temp[['Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4']].astype('str').agg(';'.join, axis=1) 
#     vR_temp['Question'] = ';'.join(['Question 1', 'Question 2', 'Question 3', 'Question 4'])
#     vR_temp['Difficulty'] = vR_temp[['question_1_difficulty', 'question_2_difficulty', 
#                                      'question_3_difficulty', 'question_4_difficulty']].astype('str').agg(';'.join, axis=1) 
#     vR_temp['Google_Translate_Error'] = vR_temp[['question_1_google_translate_error', 
#                                                  'question_2_google_translate_error', 
#                                                  'question_3_google_translate_error', 
#                                                  'question_4_google_translate_error']].astype('str').agg(';'.join, axis=1) 
#     vR_temp['Skill'] = vR_temp[['Question 1 Skill tested', 'Question 2 Skill tested', 
#                                 'Question 3 Skill tested', 'Question 4 Skill tested']].astype('str').agg(';'.join, axis=1) 
    
#     vR_temp = vR_temp.drop(['question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested', 
#                             'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
#                             'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
#                             'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
#                             'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
#                             'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
#                             'a1', 'a2', 'a3', 'a4'], axis = 1)
    
#      # Python explode function to split delimited columns and expand to rows - row_separate in R
#     vR_temp =  vR_temp.set_index(['Language', '_worker_id', '_country', 'Fluency', 'Time_Taken_Seconds',
#        '_unit_id', 'title', 'test_', 'register', 'topic', 'text_type',
#        'complexity', 'familiarity']).apply(lambda x: x.str.split(';').explode()).reset_index()
    
#     vR_temp[['Score', 'Rater_Answer', 'Actual_Answer', 'Question', 'Difficulty', 'Google_Translate_Error', 'Skill']] = vR_temp[['Score', 'Rater_Answer', 
#                                                                                                                                 'Actual_Answer','Question', 
#                                                                                                                                 'Difficulty', 
#                                                                                                                                 'Google_Translate_Error', 
#                                                                                                                                 'Skill']].replace('nan', np.nan)
#     vR_temp = vR_temp.dropna(subset = ['Score'])  # remove rows with NaN values in Score 
#     vR_temp['Score'] = vR_temp['Score'].astype('int') # set Score as integer
    
#     rc_answer_actual = vR_temp
    
#     return rc_answer_actual

# def rc_q_s_pass_rate_3A(rc_answer):
    
#     # first grouping
#     vR_grouped = rc_answer.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Score', 'Question', 'Difficulty', 'register', 'Skill'])['_worker_id'].count().reset_index()
#     vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count"})
    
#     # second grouping
#     vR_grouped['Total'] = vR_grouped.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Question', 'Difficulty', 'register', 'Skill'])['Count'].transform('sum')   
#     vR_grouped['Fail_Rate'] = round((vR_grouped['Count'] / vR_grouped['Total']), 2)
    
#     # filter Score 0 
#     vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
#     # sort values by Market and _unit_id 
#     vR_grouped = vR_grouped.sort_values(['Fluency', 'Fail_Rate'], ascending = [True, False])
#     vR_grouped = vR_grouped.reset_index(drop=True) #re-order df index
    
#     rc_question_skill_pass_rate = vR_grouped
    
#     return rc_question_skill_pass_rate

# def generate_report_3_3A(rcR):
    
#     rc_answer = rc_fail_rate_3A(rcR)
    
#     rc_choices, actual_answer, rater_answer = melt_rc_3A(rcR)
    
#     rc_answer_actual = melt_rc_answer_actual_3A(rcR)
    
#     rc_question_skill_pass_rate = rc_q_s_pass_rate_3A(rc_answer)
    
#     return rc_question_skill_pass_rate

# %% [markdown]
# #### REPORT 4 : "RC with Answers" : rc_question_skill_pass_rate_answer_final

# %%
# def rc_q_s_pass_rate_answer_3A(rc_answer_actual):
    
#     # first grouping
#     vR_grouped = rc_answer_actual.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Actual_Answer', 'Rater_Answer', 
#                                     'Score', 'Question', 'Difficulty', 'register', 'Skill'])['_worker_id'].count().reset_index()
#     vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count"})
    
#     # second grouping
#     vR_grouped['Total'] = vR_grouped.groupby(['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Question', 'Difficulty', 'register', 'Skill'])['Count'].transform('sum')   
#     vR_grouped['Fail_Rate'] = round((vR_grouped['Count'] / vR_grouped['Total']), 2)
    
#     # filter Score 0 
#     vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
#     # sort values by Market and _unit_id 
#     vR_grouped = vR_grouped.sort_values(['Fluency', '_unit_id', 'Question', 'Fail_Rate'], ascending = [True, True, True, False])
#     vR_grouped = vR_grouped.reset_index(drop=True) #re-order df index
    
#     rc_question_skill_pass_rate_answer = vR_grouped
    
#     return rc_question_skill_pass_rate_answer

# def join_rc_q_s_pass_rate_answer_3A(rc_question_skill_pass_rate_answer, actual_answer, rater_answer):
    
#     first_join = rc_question_skill_pass_rate_answer
#     first_join = pd.merge(first_join, actual_answer, how = 'left', 
#                             left_on = ["Language", "_unit_id", "title" , "test_", "Question", "Actual_Answer"],
#                             right_on = ["Language", "_unit_id", "title" , "test_", "Question", "Answer"])
#     first_join = first_join.drop('Answer', axis=1)
    
#     second_join = pd.merge(first_join, rater_answer, how = 'left', 
#                             left_on = ["Language", "_unit_id", "title" , "test_", "Question", "Rater_Answer"],
#                             right_on = ["Language", "_unit_id", "title" , "test_", "Question", "Answer"])
#     second_join = second_join.drop('Answer', axis=1)
    
#     second_join = second_join[['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Difficulty', 'register', 'Skill', 'Question',
#                                'Actual_Answer', 'value_x', 'Rater_Answer', 'value_y', 'Count', 'Total', 'Fail_Rate']]
  
#     second_join = second_join.rename(columns = { "Actual_Answer" : "Actual_Answer_Letter", 
#                                        "value_x" : "Actual_Answer_Text",
#                                        "Rater_Answer" : "Rater_Answer_Letter",
#                                        "value_y" : "Rater_Answer_Text"})

#     rc_question_skill_pass_rate_answer_final = second_join
    
#     return rc_question_skill_pass_rate_answer_final


# def generate_report_4_3A(rcR):
    
#     rc_choices, actual_answer, rater_answer = melt_rc_3A(rcR)
    
#     rc_answer_actual = melt_rc_answer_actual_3A(rcR)
    
#     rc_question_skill_pass_rate_answer = rc_q_s_pass_rate_answer_3A(rc_answer_actual)

#     rc_question_skill_pass_rate_answer_final = join_rc_q_s_pass_rate_answer_3A(rc_question_skill_pass_rate_answer, actual_answer, rater_answer)
    
#     return rc_question_skill_pass_rate_answer_final

# %% [markdown]
# ### PILOT 1A-1B

# %% [markdown]
# #### REPORT 1 : "Near Exact Match" - v1_actual_correct_by_question

# %%
def v1_fail_rate_1A_1B(v1R):  #Valid for 3A
    
    vR_temp = v1R[['Language', 'Fluency', 'Tenure', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 
                    'wordphrase_a', 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score']]
       
    # first grouping
    vR_grouped = vR_temp.groupby(['Language', 'Fluency', 'Tenure', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
    # second grouping
    vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Fluency', 'Tenure', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                    'b_domain', 'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and Fail_rate descending 
    vR_grouped = vR_grouped.sort_values(['Fluency', 'Tenure', 'Fail_Rate'], ascending=[True, True, False])
    
    vR_fail_rates = vR_grouped.reset_index(drop=True) #re-order df index
    
    return vR_fail_rates

def generate_report_1_1A_1B(v1R):
    
    v1_actual_correct_by_question = v1_fail_rate_1A_1B(v1R)
    
    return v1_actual_correct_by_question

# %% [markdown]
# #### REPORT 2 : "Close Match" - v2_fail_rates

# %%
def v2_fail_rate_1A_1B(v2R):
    
    vR_temp = v2R[['Language', 'Fluency', 'Tenure', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                   'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score']]
    
    # first grouping
    vR_grouped = vR_temp.groupby(['Language', 'Fluency', 'Tenure', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                                  'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
    # second grouping
    vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Fluency', 'Tenure', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                    'b_domain', 'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', 'Tenure', 'Fail_Rate'], ascending = [True, True, False])
    
    # drop Score column
    vR_grouped = vR_grouped.drop('Score', axis = 1)
    
    vR_fail_rates = vR_grouped.reset_index(drop=True) #re-order df index
    
    return vR_fail_rates

def v2_fail_rate_2_1A_1B(v2R):
    
    vR_temp = v2R[['Language', 'Fluency', 'Tenure', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                   'b_register', 'wordphrase_b', 'difficulty', 'rater_answer', 'Answer', 'Score']]
    
    # first grouping
    vR_grouped = vR_temp.groupby(['Language', 'Fluency', 'Tenure', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                                  'b_register', 'wordphrase_b', 'difficulty', 'rater_answer', 'Answer', 'Score'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
    # second grouping
    vR_grouped['Total_Test_Takers'] = vR_grouped.groupby(['Fluency', 'Tenure', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 'b_domain', 
                                                          'b_register', 'wordphrase_b', 'difficulty'])['Count_of_Test_Takers'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count_of_Test_Takers'] / vR_grouped['Total_Test_Takers']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['Score'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', 'Tenure', '_unit_id', 'Fail_Rate'], ascending = [True, True, True, False])
    
    v2_actual_correct_by_question_with_answer = vR_grouped
    
    return v2_actual_correct_by_question_with_answer

def generate_report_2_1A_1B(v2R):
    
    v2_actual_correct_by_question = v2_fail_rate_1A_1B(v2R)

    v2_actual_correct_by_question_with_answer = v2_fail_rate_2_1A_1B(v2R)

    return v2_actual_correct_by_question_with_answer

# %% [markdown]
# #### REPORT 3 : "Reading Comprehension" : rc_question_skill_pass_rate

# %%
def rc_fail_rate_1A_1B(rcR):

    vR_temp = rcR[['Language', '_worker_id', '_country', 'Fluency', 'Tenure', 'Time_Taken_Seconds', '_unit_id', 'title',
                'question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested',
                'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                'register', 'topic', 'text_type', 'complexity', 'familiarity', 
                'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
                'Score']]
    
    # evaluate if Answers are the same as the questions. If either Q or A are empty, return NaN
    if vR_temp['question_no_1'].isnull().all() == True or vR_temp['Answer_no_1'].isnull().all() == True:      
        vR_temp['a1'] = np.nan      
    else:   
        vR_temp['a1'] = np.where(vR_temp['question_no_1'] == vR_temp['Answer_no_1'], 1, 0).astype('str')
        
    if vR_temp['question_no_2'].isnull().all() == True or vR_temp['Answer_no_2'].isnull().all() == True:        
        vR_temp['a2'] = np.nan      
    else:       
        vR_temp['a2'] = np.where(vR_temp['question_no_2'] == vR_temp['Answer_no_2'], 1, 0).astype('str')      
        
    if vR_temp['question_no_3'].isnull().all() == True or vR_temp['Answer_no_3'].isnull().all() == True:  
        vR_temp['a3'] = np.nan 
    else:
        vR_temp['a3'] = np.where(vR_temp['question_no_3'] == vR_temp['Answer_no_3'], 1, 0).astype('str')
        
    if vR_temp['question_no_4'].isnull().all() == True or vR_temp['Answer_no_4'].isnull().all() == True:   
        vR_temp['a4'] = np.nan 
    else:
        vR_temp['a4'] = np.where(vR_temp['question_no_4'] == vR_temp['Answer_no_4'], 1, 0).astype('str')
    
    # Dropping columns
    vR_temp = vR_temp.drop(['question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                            'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4', 'Score'], axis =1)  
    
    # concatenate values from different columns with delimiter ;
    vR_temp['a'] = vR_temp[['a1', 'a2', 'a3', 'a4']].astype('str').agg(';'.join, axis=1) 
    vR_temp['q'] = ';'.join(['Question 1', 'Question 2', 'Question 3', 'Question 4'])
    vR_temp['d'] = vR_temp[['question_1_difficulty', 'question_2_difficulty', 
                                     'question_3_difficulty', 'question_4_difficulty']].astype('str').agg(';'.join, axis=1) 
    vR_temp['ge'] = vR_temp[['question_1_google_translate_error', 
                                                 'question_2_google_translate_error', 
                                                 'question_3_google_translate_error', 
                                                 'question_4_google_translate_error']].astype('str').agg(';'.join, axis=1) 
    vR_temp['skill'] = vR_temp[['Question 1 Skill tested', 'Question 2 Skill tested', 
                                'Question 3 Skill tested', 'Question 4 Skill tested']].astype('str').agg(';'.join, axis=1) 
    
    # Dropping more columns
    vR_temp = vR_temp.drop(['question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested', 
                            'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                            'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                            'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                            'a1', 'a2', 'a3', 'a4'], axis =1)  
    
    # Python explode function to split delimited columns and expand to rows - row_separate in R
    vR_temp =  vR_temp.set_index(['Language', '_worker_id', '_country', 'Fluency', 'Tenure', 'Time_Taken_Seconds',
       '_unit_id', 'title', 'register', 'topic', 'text_type',
       'complexity', 'familiarity']).apply(lambda x: x.str.split(';').explode()).reset_index()
    
    vR_temp[['a', 'q', 'd', 'ge', 'skill']] = vR_temp[['a', 'q', 'd', 'ge', 'skill']].replace('nan', np.nan)
    vR_temp = vR_temp.dropna(subset = ['a'])  # remove rows with NaN values in Score 
    vR_temp['a'] = vR_temp['a'].astype('int') # set Score as integer
    
    rc_answer = vR_temp
    
    return vR_temp

# ## Melt RC into long format with actual answers
def melt_rc_answer_actual_1A_1B(rcR):
    
    vR_temp = rcR[['Language', '_worker_id', '_country', 'Fluency', 'Tenure', 'Time_Taken_Seconds', '_unit_id', 'title',
                'question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested',
                'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                'register', 'topic', 'text_type', 'complexity', 'familiarity',
                'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
                'Score']]
    
    # evaluate if Answers are the same as the questions. If either Q or A are empty, return NaN
    if vR_temp['question_no_1'].isnull().all() == True or vR_temp['Answer_no_1'].isnull().all() == True:      
        vR_temp['a1'] = np.nan      
    else:   
        vR_temp['a1'] = np.where(vR_temp['question_no_1'] == vR_temp['Answer_no_1'], 1, 0).astype('str')
        
    if vR_temp['question_no_2'].isnull().all() == True or vR_temp['Answer_no_2'].isnull().all() == True:        
        vR_temp['a2'] = np.nan      
    else:       
        vR_temp['a2'] = np.where(vR_temp['question_no_2'] == vR_temp['Answer_no_2'], 1, 0).astype('str')      
        
    if vR_temp['question_no_3'].isnull().all() == True or vR_temp['Answer_no_3'].isnull().all() == True:  
        vR_temp['a3'] = np.nan 
    else:
        vR_temp['a3'] = np.where(vR_temp['question_no_3'] == vR_temp['Answer_no_3'], 1, 0).astype('str')
        
    if vR_temp['question_no_4'].isnull().all() == True or vR_temp['Answer_no_4'].isnull().all() == True:   
        vR_temp['a4'] = np.nan 
    else:
        vR_temp['a4'] = np.where(vR_temp['question_no_4'] == vR_temp['Answer_no_4'], 1, 0).astype('str')
    
    vR_temp = vR_temp.drop('Score', axis = 1)
    
    # concatenate values from different columns with delimiter ;
    vR_temp['a'] = vR_temp[['a1', 'a2', 'a3', 'a4']].astype('str').agg(';'.join, axis=1) 
    vR_temp['ra'] = vR_temp[['question_no_1', 'question_no_2', 'question_no_3', 'question_no_4']].astype('str').agg(';'.join, axis=1)
    vR_temp['aa'] = vR_temp[['Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4']].astype('str').agg(';'.join, axis=1) 
    vR_temp['q'] = ';'.join(['Question 1', 'Question 2', 'Question 3', 'Question 4'])
    vR_temp['d'] = vR_temp[['question_1_difficulty', 'question_2_difficulty', 
                                     'question_3_difficulty', 'question_4_difficulty']].astype('str').agg(';'.join, axis=1) 
    vR_temp['ge'] = vR_temp[['question_1_google_translate_error', 
                                                 'question_2_google_translate_error', 
                                                 'question_3_google_translate_error', 
                                                 'question_4_google_translate_error']].astype('str').agg(';'.join, axis=1) 
    vR_temp['skill'] = vR_temp[['Question 1 Skill tested', 'Question 2 Skill tested', 
                                'Question 3 Skill tested', 'Question 4 Skill tested']].astype('str').agg(';'.join, axis=1) 
    
    vR_temp = vR_temp.drop(['question_1_difficulty', 'question_1_google_translate_error', 'Question 1 Skill tested', 
                            'question_2_difficulty', 'question_2_google_translate_error', 'Question 2 Skill tested',
                            'question_3_difficulty', 'question_3_google_translate_error', 'Question 3 Skill tested',
                            'question_4_difficulty', 'question_4_google_translate_error', 'Question 4 Skill tested',
                            'question_no_1', 'question_no_2', 'question_no_3', 'question_no_4',
                            'Answer_no_1', 'Answer_no_2', 'Answer_no_3', 'Answer_no_4',
                            'a1', 'a2', 'a3', 'a4'], axis = 1)
    
     # Python explode function to split delimited columns and expand to rows - row_separate in R
    vR_temp =  vR_temp.set_index(['Language', '_worker_id', '_country', 'Fluency', 'Tenure', 'Time_Taken_Seconds',
       '_unit_id', 'title', 'register', 'topic', 'text_type',
       'complexity', 'familiarity']).apply(lambda x: x.str.split(';').explode()).reset_index()
    
    vR_temp[['a', 'ra', 'aa', 'q', 'd', 'ge', 'skill']] = vR_temp[['a', 'ra', 'aa', 'q', 'd', 'ge', 'skill']].replace('nan', np.nan)
    vR_temp = vR_temp.dropna(subset = ['a'])  # remove rows with NaN values in Score 
    vR_temp['a'] = vR_temp['a'].astype('int') # set Score as integer
    
    rc_answer_actual = vR_temp
    
    return rc_answer_actual

def rc_q_s_pass_rate_1A_1B(rc_answer):
    
    # first grouping
    vR_grouped = rc_answer.groupby(['Language', 'Fluency', 'Tenure', '_unit_id', 'title', 'a', 'q', 'd', 'register', 'skill'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count"})
    
    # second grouping
    vR_grouped['Total'] = vR_grouped.groupby(['Language', 'Fluency', 'Tenure', '_unit_id', 'title', 'q', 'd', 'register', 'skill'])['Count'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count'] / vR_grouped['Total']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['a'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', 'Tenure', 'Fail_Rate'], ascending = [True, True, False])
    vR_grouped = vR_grouped.reset_index(drop=True) #re-order df index
    
    rc_question_skill_pass_rate = vR_grouped
    
    return rc_question_skill_pass_rate

def generate_report_3_1A_1B(rcR):
    
    rc_answer = rc_fail_rate_1A_1B(rcR)
    
    rc_answer_actual = melt_rc_answer_actual_1A_1B(rcR)
    
    rc_question_skill_pass_rate = rc_q_s_pass_rate_1A_1B(rc_answer)
    
    return rc_question_skill_pass_rate

# %% [markdown]
# #### REPORT 4 : "RC with Answers" : rc_question_skill_pass_rate_answer_final

# %%
def rc_q_s_pass_rate_answer_1A_1B(rc_answer_actual):
    
    # first grouping
    vR_grouped = rc_answer_actual.groupby(['Language', 'Fluency', 'Tenure', '_unit_id', 'title', 'aa', 'ra', 'a', 'q', 'd', 'register', 'skill'])['_worker_id'].count().reset_index()
    vR_grouped = vR_grouped.rename(columns = {"_worker_id" : "Count"})
    
    # second grouping
    vR_grouped['Total'] = vR_grouped.groupby(['Language', 'Fluency', 'Tenure', '_unit_id', 'title', 'q', 'd', 'register', 'skill'])['Count'].transform('sum')   
    vR_grouped['Fail_Rate'] = round((vR_grouped['Count'] / vR_grouped['Total']), 2)
    
    # filter Score 0 
    vR_grouped = vR_grouped[vR_grouped['a'] == 0]
    
    # sort values by Market and _unit_id 
    vR_grouped = vR_grouped.sort_values(['Fluency', 'Tenure', '_unit_id', 'q', 'Fail_Rate'], ascending = [True, True, True, True, False])
    vR_grouped = vR_grouped.reset_index(drop=True) #re-order df index
    
    rc_question_skill_pass_rate_answer = vR_grouped
    
    return rc_question_skill_pass_rate_answer

# def join_rc_q_s_pass_rate_answer_1A_1B(rc_question_skill_pass_rate_answer, actual_answer, rater_answer):
    
#     first_join = rc_question_skill_pass_rate_answer
#     first_join = pd.merge(first_join, actual_answer, how = 'left', 
#                             left_on = ["Language", "_unit_id", "title" , "test_", "Question", "Actual_Answer"],
#                             right_on = ["Language", "_unit_id", "title" , "test_", "Question", "Answer"])
#     first_join = first_join.drop('Answer', axis=1)
    
#     second_join = pd.merge(first_join, rater_answer, how = 'left', 
#                             left_on = ["Language", "_unit_id", "title" , "test_", "Question", "Rater_Answer"],
#                             right_on = ["Language", "_unit_id", "title" , "test_", "Question", "Answer"])
#     second_join = second_join.drop('Answer', axis=1)
    
#     second_join = second_join[['Language', 'Fluency', '_unit_id', 'title', 'test_', 'Difficulty', 'register', 'Skill', 'Question',
#                                'Actual_Answer', 'value_x', 'Rater_Answer', 'value_y', 'Count', 'Total', 'Fail_Rate']]
  
#     second_join = second_join.rename(columns = { "Actual_Answer" : "Actual_Answer_Letter", 
#                                        "value_x" : "Actual_Answer_Text",
#                                        "Rater_Answer" : "Rater_Answer_Letter",
#                                        "value_y" : "Rater_Answer_Text"})

#     rc_question_skill_pass_rate_answer_final = second_join
    
#     return rc_question_skill_pass_rate_answer_final


def generate_report_4_1A_1B(rcR):
    
#     rc_choices, actual_answer, rater_answer = melt_rc_1A_1B(rcR)
    
    rc_answer_actual = melt_rc_answer_actual_1A_1B(rcR)
    
    rc_question_skill_pass_rate_answer_final = rc_q_s_pass_rate_answer_1A_1B(rc_answer_actual)  #THIS ONE

#     rc_question_skill_pass_rate_answer_final = join_rc_q_s_pass_rate_answer_1A_1B(rc_question_skill_pass_rate_answer, actual_answer, rater_answer)
    
    return rc_question_skill_pass_rate_answer_final

# %%
def generate_all_fail_rate_reports(rcR, v1R, v2R, rc, v1, v2, run_value, pilot_var_selected):
    
    if pilot_var_selected == 'Pilot 3A':
        
        # Report 1 - Near Exact Match - v1_actual_correct_by_question
        v1_actual_correct_by_question =  generate_report_1_3A(v1R)

        # Report 2 - Close Match - v2_fail_rates
        v2_fail_rates = generate_report_2_3A(v2R)

        # Report 3 - Reading Comprehension - rc_question_skill_pass_rate
        rc_question_skill_pass_rate = generate_report_3_3A(rcR)

        # Report 4 - RC with Answers - rc_question_skill_pass_rate_answer_final
        rc_question_skill_pass_rate_answer_final = generate_report_4_3A(rcR)

        # store all 4 reports into a dictionary set
        list_of_datasets = {"Near Exact Match" : v1_actual_correct_by_question,
                            "Close Match" : v2_fail_rates,
                            "Reading Comprehension" : rc_question_skill_pass_rate,
                            "RC with Answers" : rc_question_skill_pass_rate_answer_final}

        if run_value == 'Deployment':

            # store all 3 summaries into a dictionary set
            list_of_summaries = {"deployment_rc" : rc,
                                "deployment_v1" : v1,
                                "deployment_v2" : v2}

        else:

            # store all 3 summaries into a dictionary set
            list_of_summaries = { run_value + "_rc" : rc,
                                  run_value + "_v1" : v1,
                                  run_value + "_v2" : v2}
            
            
    elif pilot_var_selected == 'Pilot 1A-1B':
        
        # Report 1 - Near Exact Match - v1_actual_correct_by_question
        v1_actual_correct_by_question =  generate_report_1_1A_1B(v1R)

        # Report 2 - Close Match - v2_fail_rates
        v2_fail_rates = generate_report_2_1A_1B(v2R)

        # Report 3 - Reading Comprehension - rc_question_skill_pass_rate
        rc_question_skill_pass_rate = generate_report_3_1A_1B(rcR)

        # Report 4 - RC with Answers - rc_question_skill_pass_rate_answer_final
        rc_question_skill_pass_rate_answer_final = generate_report_4_1A_1B(rcR)

        # store all 4 reports into a dictionary set
        list_of_datasets = {"Near Exact Match" : v1_actual_correct_by_question,
                            "Close Match" : v2_fail_rates,
                            "Reading Comprehension" : rc_question_skill_pass_rate,
                            "RC with Answers" : rc_question_skill_pass_rate_answer_final}

        if run_value == 'Deployment':

            # store all 3 summaries into a dictionary set
            list_of_summaries = {"deployment_rc" : rc,
                                "deployment_v1" : v1,
                                "deployment_v2" : v2}

        else:

            # store all 3 summaries into a dictionary set
            list_of_summaries = { run_value + "_rc" : rc,
                                  run_value + "_v1" : v1,
                                  run_value + "_v2" : v2}

    
    return list_of_datasets, list_of_summaries

def file_check_create(root_path, config, language_selected, run_value, pilot_var_selected):
    
    if run_value == 'Deployment':
        
        run_folder = os.path.join(root_path, config['report']['deliverable'], run_value, language_selected)

        if not os.path.exists(run_folder):
            os.makedirs(run_folder, exist_ok=True)
        
        folder_tag = 'Deployment Summary'
        analysis_folder = os.path.join(root_path, config['report']['analysis'], folder_tag)

        if not os.path.exists(analysis_folder):
            os.makedirs(analysis_folder, exist_ok=True)
            
        if not os.path.exists(os.path.join(analysis_folder, 'RC')):
            os.makedirs(os.path.join(analysis_folder, 'RC'), exist_ok=True)
            
        if not os.path.exists(os.path.join(analysis_folder, 'V1')):
            os.makedirs(os.path.join(analysis_folder, 'V1'), exist_ok=True)
            
        if not os.path.exists(os.path.join(analysis_folder, 'V2')):
            os.makedirs(os.path.join(analysis_folder, 'V2'), exist_ok=True)
            
    else:
        
        run_folder = os.path.join(root_path, config['report']['deliverable'], run_value, pilot_var_selected, language_selected)

        if not os.path.exists(run_folder):
            os.makedirs(run_folder, exist_ok=True)
            
        folder_tag = 'Grand Summary'
        analysis_folder = os.path.join(root_path, config['report']['analysis'], folder_tag)

        if not os.path.exists(analysis_folder):
            os.makedirs(analysis_folder, exist_ok=True)
            
        if not os.path.exists(os.path.join(analysis_folder, 'RC')):
            os.makedirs(os.path.join(analysis_folder, 'RC'), exist_ok=True)
            
        if not os.path.exists(os.path.join(analysis_folder, 'V1')):
            os.makedirs(os.path.join(analysis_folder, 'V1'), exist_ok=True)
            
        if not os.path.exists(os.path.join(analysis_folder, 'V2')):
            os.makedirs(os.path.join(analysis_folder, 'V2'), exist_ok=True)
        
    return run_folder, analysis_folder, folder_tag

def write_fail_report_to_excel(run_folder, list_of_datasets, encode=None):
    
    with pd.ExcelWriter(os.path.join(run_folder, 'language_fail_rates.xlsx')) as writer:  
        for key, value in list_of_datasets.items():
            value.to_excel(writer, sheet_name=key, index=False, encoding=encode)
            
def write_summary_to_csv(analysis_folder, list_of_summaries, encode=None):
    
    folders = ['RC', 'V1', 'V2']
    for lists, f in zip(list_of_summaries.items(), folders):
        key, value = lists[0], lists[1]
        value.to_csv(os.path.join(os.path.join(analysis_folder,f), key + '.csv'), index=False, encoding=encode)

# %% [markdown]
# #### Run all

# %%
def main():
    
    print('\nData processing in progress...')
    # import data from data_processing module
    raters, r1, r2, r3, languages, rc, v1, v2, run_value , run_value_2, survey_selected, survey_files, pilot_variation, pilot_selected, pilot_var_selected = data_processing.main()
    print('Data processing completed.')
    print("\n")
    print(languages)
    
    # Get input language selection
    language_selected = language_selection(languages)
      
    # Get data from language modification processes
    rcR, v1R, v2R = get_time_taken_all(language_selected, rc, v1, v2)
    
    print('\nGenerating reports ...')
    
    # Start generating fail rate reports
    list_of_datasets, list_of_summaries = generate_all_fail_rate_reports(rcR, v1R, v2R, rc, v1, v2, run_value, pilot_var_selected)
    
    # Check the run type and language and create folders in reports > deliverables
    run_folder, analysis_folder, folder_tag = file_check_create(root_path, config, language_selected, run_value, pilot_var_selected)
    
    # Write reports to excel file in run_folder path
    write_fail_report_to_excel(run_folder, list_of_datasets, encode=None)
    
    print(f"\n1. Language fail rates report completed and stored in reports > deliverables > {run_value} > {pilot_var_selected} > {language_selected}")
    
    # Write summaries to csv file in analysis_folder path
    write_summary_to_csv(analysis_folder, list_of_summaries, encode=None)
    
    print(f"\n2. Summary report completed and stored in analysis > {folder_tag} > RC/V1/V2")
    
    return r1, r2, r3, rc, v1, v2, pilot_var_selected, rcR, v1R, v2R, list_of_datasets, list_of_summaries
    
if __name__ == "__main__":
     
    r1, r2, r3, rc, v1, v2, pilot_var_selected, rcR, v1R, v2R, list_of_datasets, list_of_summaries = main()
# Out:
# Data processing in progress...
# Initialize data ingestion and file checking...
#
# PASS: All files exists!
# Please input the type of run e.g. Deployment, Pilot 1, Pilot 2, Pilot 3 .... etc.:  Pilot 1
# Run type: Pilot 1
# Please input the pilot subfolder name e.g. Pilot 1A, Pilot 2C, Pilot 3A-B .... etc.:  Pilot 1A-1B
# Pilot subfolder: Pilot 1A-1B
# Do you know the 'Language' and/or 'Market code' for this file? (y/n) :  y
#
# Please enter the Language:  French
#
# Please enter the Market code: eg. EN-EN for English :  FR-FR
# Starting automated data cleaning....
#
# Dataframe created from RC file
# Language and Market columns and values inserted to 'Summary' sheet
# Language column and values inserted to 'Data' sheet
# Missing columns inserted into 'Data' sheet.
#
# Preview cleaned datasets:
#
#
#
# df_summary_cleaned
#
#
#   Language Market  _worker_id  Score  Percentage  Grouping
# 0   French  FR-FR    45505292     10    0.833333  Pilot 1A
# 1   French  FR-FR    45631921     10    0.833333  Pilot 1A
# 2   French  FR-FR    45781379     12    1.000000  Pilot 1A
# 3   French  FR-FR    45483220     12    1.000000  Pilot 1A
# 4   French  FR-FR    45688723     11    0.916667  Pilot 1A
#
#
# df_data_cleaned
#
#
#   Language         _id question_no_1 question_no_2 question_no_3  \
# 0   French  5700206236             c             a             a
# 1   French  5700215923             c             a             a
# 2   French  5700345459             c             a             a
# 3   French  5700581103             c             a             a
# 4   French  5700977804             c             a             a
#
#    question_no_4  question_no_5
# 0            NaN            NaN
# 1            NaN            NaN
# 2            NaN            NaN
# 3            NaN            NaN
# 4            NaN            NaN
#
# Data integrity report post clean-up:
#
# Reading RC raw data and perform data integrity scanning...:
#
#
# SCAN-1 : RC - Summary : Checking if the sheet contains either 'Language' and 'Market' columns ...
# PASS: 'Summary' sheet contains both 'Language' and 'Market' columns
#
# SCAN-2 : RC - Summary : Checking if Language' and 'Market' columns are empty ...
# PASS: Both 'Language' and 'Market' columns in 'Summary' contains complete data
#
# SCAN-3 : RC - Summary : Checking if '_worker_id' column name is correct ...
# PASS: valid '_workder_id' column name
#
# SCAN-4 : RC - Data : Checking if sheet contains 'Language' column ...
# PASS: 'Data' sheet contains 'Language' columns
#
# SCAN-5 : RC - Data : Checking if Language' column are empty ...
# PASS: 'Language'column in 'Data' contains complete data
#
# SCAN-6 : RC - Data : Checking if '_worker_id' column name is correct ...
# PASS: valid '_workder_id' column name
#
# SCAN-7 : RC - Data : checking if columns in the 'Data' sheet are identical to the reference columns ...
# PASS: The columns in the 'Data' sheet are identical to the reference
#
# RC data integrity result: PASS
#
# Dataframe created from Vocab_1 file
# Language and Market columns and values inserted to 'Summary' sheet
# Language column and values inserted to 'Data' sheet
# Removing unwanted columns from Vocab_1 Data sheet
#
# Preview cleaned datasets:
#
#
#
# df_summary_cleaned
#
#
#   Language Market  _worker_id  Score  Percentage  Grouping
# 0   French  FR-FR    45505292     18        0.90  Pilot 1A
# 1   French  FR-FR    45631921     16        0.80  Pilot 1A
# 2   French  FR-FR    45781379     18        0.90  Pilot 1A
# 3   French  FR-FR    45483220      4        0.20  Pilot 1A
# 4   French  FR-FR    45688723     17        0.85  Pilot 1A
#
#
# df_data_cleaned
#
#
#   Language         _id rater_answer  a_domain a_register  b_domain b_register
# 0   French  5700185097          yes  shopping    neutral  shopping    neutral
# 1   French  5700196181          yes  shopping    neutral  shopping    neutral
# 2   French  5700332590          yes  shopping    neutral  shopping    neutral
# 3   French  5700566722           no  shopping    neutral  shopping    neutral
# 4   French  5700963570          yes  shopping    neutral  shopping    neutral
#
# Data integrity report post clean-up:
#
# Reading Vocab_1 raw data and perform data integrity scanning...:
#
#
# SCAN-1 : Vocab_1 - Summary : Checking if the sheet contains either 'Language' and 'Market' columns ...
# PASS: 'Summary' sheet contains both 'Language' and 'Market' columns
#
# SCAN-2 : Vocab_1 - Summary : Checking if Language' and 'Market' columns are empty ...
# PASS: Both 'Language' and 'Market' columns in 'Summary' contains complete data
#
# SCAN-3 : Vocab_1 - Summary : Checking if '_worker_id' column name is correct ...
# PASS: valid '_workder_id' column name
#
# SCAN-4 : Vocab_1 - Data : Checking if sheet contains 'Language' column ...
# PASS: 'Data' sheet contains 'Language' columns
#
# SCAN-5 : Vocab_1 - Data : Checking if Language' column are empty ...
# PASS: 'Language'column in 'Data' contains complete data
#
# SCAN-6 : Vocab_1 - Data : Checking if '_worker_id' column name is correct ...
# PASS: valid '_workder_id' column name
#
# Vocab_1 data integrity result: PASS
#
# Dataframe created from Vocab_2 file
# Language and Market columns and values inserted to 'Summary' sheet
# Language column and values inserted to 'Data' sheet
# Removing unwanted columns from Vocab_2 Data sheet
#
# Preview cleaned datasets:
#
#
#
# df_summary_cleaned
#
#
#   Language Market  _worker_id  Score  Percentage  Grouping
# 0   French  FR-FR    45505292     32       0.800  Pilot 1A
# 1   French  FR-FR    45631921     25       0.625  Pilot 1A
# 2   French  FR-FR    45781379     33       0.825  Pilot 1A
# 3   French  FR-FR    45781725      3       0.075  Pilot 1A
# 4   French  FR-FR    45483220     26       0.650  Pilot 1A
#
#
# df_data_cleaned
#
#
#   Language         _id                   rater_answer a_domain  \
# 0   French  5700186158  a_and_b_have_the_same_meaning  leisure
# 1   French  5700200727      b_is_more_specific_than_a  leisure
# 2   French  5700335878            a_and_b_are_related  leisure
# 3   French  5700390611            a_and_b_are_related  leisure
# 4   French  5700567781            a_and_b_are_related  leisure
#
#        a_register b_domain b_register
# 0  slang/informal  leisure    neutral
# 1  slang/informal  leisure    neutral
# 2  slang/informal  leisure    neutral
# 3  slang/informal  leisure    neutral
# 4  slang/informal  leisure    neutral
#
# Data integrity report post clean-up:
#
# Reading Vocab_2 raw data and perform data integrity scanning...:
#
#
# SCAN-1 : Vocab_2 - Summary : Checking if the sheet contains either 'Language' and 'Market' columns ...
# PASS: 'Summary' sheet contains both 'Language' and 'Market' columns
#
# SCAN-2 : Vocab_2 - Summary : Checking if Language' and 'Market' columns are empty ...
# PASS: Both 'Language' and 'Market' columns in 'Summary' contains complete data
#
# SCAN-3 : Vocab_2 - Summary : Checking if '_worker_id' column name is correct ...
# PASS: valid '_workder_id' column name
#
# SCAN-4 : Vocab_2 - Data : Checking if sheet contains 'Language' column ...
# PASS: 'Data' sheet contains 'Language' columns
#
# SCAN-5 : Vocab_2 - Data : Checking if Language' column are empty ...
# PASS: 'Language'column in 'Data' contains complete data
#
# SCAN-6 : Vocab_2 - Data : Checking if '_worker_id' column name is correct ...
# PASS: valid '_workder_id' column name
#
# Vocab_2 data integrity result: PASS
#
# Automated data cleaning completed. Cleaned excel files are located in data > processed > Pilot 1 folder.
#
# Initialize data ingestion and file checking...
#
#
#
#      Pilot    Variation
# 0  Pilot 1  Pilot 1A-1B
# 1  Pilot 1     Pilot 1C
# 2  Pilot 1     Pilot 1D
# 3  Pilot 1     Pilot 1E
# 4  Pilot 2     Pilot 2A
# 5  Pilot 2   Pilot 2A-A
# 6  Pilot 2   Pilot 2B-A
# 7  Pilot 2     Pilot 2D
# 8  Pilot 3     Pilot 3A
# 9  Pilot 3   Pilot 3A-A
# Please select the number of the pilot variation:  0
# You have selected 0 for 'Pilot 1A-1B'
#
#                Survey Filename
# 0  Survey Pilot 1A and 1B.xlsx
# 1          Survey Pilot 2.xlsx
# 2    Survey Pilot 2 and 3.xlsx
# Please select the number of the survey filename for your pilot run:  0
# You have selected 0 for 'Survey Pilot 1A and 1B.xlsx'
#
# Data processing completed.
#
#
#   Language
# 0   French
# Please select the number of the Language you are assessing:  0
# You have selected 0 for French
#
# Generating reports ...
#
# 1. Language fail rates report completed and stored in reports > deliverables > Pilot 1 > Pilot 1A-1B > French
#
# 2. Summary report completed and stored in analysis > Grand Summary > RC/V1/V2

# %%
rc
# Out:
#     Language         _id question_no_1 question_no_2 question_no_3  \
# 0     French  5700206236             c             a             a
# 1     French  5700215923             c             a             a
# 2     French  5700345459             c             a             a
# 3     French  5700581103             c             a             a
# 4     French  5700977804             c             a             a
# ..       ...         ...           ...           ...           ...
# 123   French  5713289134             b             c             a
# 124   French  5713332465             c             a             a
# 125   French  5713341018             c             c             a
# 126   French  5713348682             c             b             c
# 127   French  5713353413             b             c             a
#
#      question_no_4  question_no_5  \
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ..             ...            ...
# 123            NaN            NaN
# 124            NaN            NaN
# 125            NaN            NaN
# 126            NaN            NaN
# 127            NaN            NaN
#
#                                                changes       complexity  \
# 0                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 1                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 2                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 3                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 4                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# ..                                                 ...              ...
# 123  Added/removed a couple of words to make the pa...  straightforward
# 124                 Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 125                                                NaN          complex
# 126  Shortened the text by removing several phrases...          complex
# 127  Added/removed a couple of words to make the pa...  straightforward
#
#     familiarity  ... If so, what were the issues?  \
# 0      familiar  ...                          NaN
# 1      familiar  ...                          NaN
# 2      familiar  ...                          NaN
# 3      familiar  ...                          NaN
# 4      familiar  ...                          NaN
# ..          ...  ...                          ...
# 123  unfamiliar  ...                          NaN
# 124    familiar  ...                          NaN
# 125    familiar  ...                          NaN
# 126  unfamiliar  ...                          NaN
# 127  unfamiliar  ...                          NaN
#
#     Did you feel you had enough time to complete the assessment in one sitting?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     If so, did you feel pressured for time? Please share your thoughts and experience.  \
# 0    I did not feel pressured for time, the timer l...
# 1                                                  NaN
# 2        I had enough time and didn't feel pressured .
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     Did you feel there was a good range of difficulty in the questions?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     Please explain your thoughts? Any details you can offer are greatly appreciated.  \
# 0    there were questions for every language levels...
# 1                                                  NaN
# 2    Items weren't so easy so it was a bit challeng...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     If so, please list what you used, and explain why you chose to use them?  \
# 0    I had to look up a word on google because I wa...
# 1                                                  NaN
# 2    I used Google search and Linguee  for mutiple ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
# 0                                                   no
# 1                                                  NaN
# 2                                                   no
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     If so, any information you can provide is helpful.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#                              Tenure
# 0                          90+ days
# 1                          90+ days
# 2                          90+ days
# 3                          90+ days
# 4                          90+ days
# ..                              ...
# 123  Google Translate Control Group
# 124  Google Translate Control Group
# 125  Google Translate Control Group
# 126  Google Translate Control Group
# 127  Google Translate Control Group
#
# [128 rows x 92 columns]

# %%
v1
# Out:
#     Language         _id rater_answer            a_domain      a_register  \
# 0     French  5700185097          yes            shopping         neutral
# 1     French  5700196181          yes            shopping         neutral
# 2     French  5700332590          yes            shopping         neutral
# 3     French  5700566722           no            shopping         neutral
# 4     French  5700963570          yes            shopping         neutral
# ..       ...         ...          ...                 ...             ...
# 624   French  5713221393          yes               books         neutral
# 625   French  5713228977          yes             science       technical
# 626   French  5713229927           no  general vocabulary         neutral
# 627   French  5713230801          yes  general vocabulary  slang/informal
# 628   French  5713231418          yes  general vocabulary          formal
#
#                b_domain      b_register difficulty familiarity  question_  \
# 0              shopping         neutral       easy    familiar         23
# 1              shopping         neutral       easy    familiar         23
# 2              shopping         neutral       easy    familiar         23
# 3              shopping         neutral       easy    familiar         23
# 4              shopping         neutral       easy    familiar         23
# ..                  ...             ...        ...         ...        ...
# 624               books          formal     medium    familiar          4
# 625             science       technical       hard  unfamiliar         15
# 626  general vocabulary         neutral       hard    familiar         37
# 627  general vocabulary  slang/informal     medium  unfamiliar         21
# 628  general vocabulary          formal     medium    familiar         31
#
#      ... If so, what were the issues?  \
# 0    ...                          NaN
# 1    ...                          NaN
# 2    ...                          NaN
# 3    ...                          NaN
# 4    ...                          NaN
# ..   ...                          ...
# 624  ...                          NaN
# 625  ...                          NaN
# 626  ...                          NaN
# 627  ...                          NaN
# 628  ...                          NaN
#
#     Did you feel you had enough time to complete the assessment in one sitting?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     If so, did you feel pressured for time? Please share your thoughts and experience.  \
# 0    I did not feel pressured for time, the timer l...
# 1                                                  NaN
# 2        I had enough time and didn't feel pressured .
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     Did you feel there was a good range of difficulty in the questions?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     Please explain your thoughts? Any details you can offer are greatly appreciated.  \
# 0    there were questions for every language levels...
# 1                                                  NaN
# 2    Items weren't so easy so it was a bit challeng...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#      Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     If so, please list what you used, and explain why you chose to use them?  \
# 0    I had to look up a word on google because I wa...
# 1                                                  NaN
# 2    I used Google search and Linguee  for mutiple ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
# 0                                                   no
# 1                                                  NaN
# 2                                                   no
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#      If so, any information you can provide is helpful.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#                              Tenure
# 0                          90+ days
# 1                          90+ days
# 2                          90+ days
# 3                          90+ days
# 4                          90+ days
# ..                              ...
# 624  Google Translate Control Group
# 625  Google Translate Control Group
# 626  Google Translate Control Group
# 627  Google Translate Control Group
# 628  Google Translate Control Group
#
# [629 rows x 46 columns]

# %%
v2
# Out:
#      Language         _id                   rater_answer        a_domain  \
# 0      French  5700186158  a_and_b_have_the_same_meaning         leisure
# 1      French  5700200727      b_is_more_specific_than_a         leisure
# 2      French  5700335878            a_and_b_are_related         leisure
# 3      French  5700390611            a_and_b_are_related         leisure
# 4      French  5700567781            a_and_b_are_related         leisure
# ...       ...         ...                            ...             ...
# 1267   French  5713305896        a_and_b_are_not_related  home furniture
# 1268   French  5713306680        a_and_b_are_not_related         clothes
# 1269   French  5713307377      b_is_more_specific_than_a      automobile
# 1270   French  5713308509        a_and_b_are_not_related      literature
# 1271   French  5713309316      a_is_more_specific_than_b       education
#
#           a_register        b_domain b_register difficulty familiarity  \
# 0     slang/informal         leisure    neutral     medium    familiar
# 1     slang/informal         leisure    neutral     medium    familiar
# 2     slang/informal         leisure    neutral     medium    familiar
# 3     slang/informal         leisure    neutral     medium    familiar
# 4     slang/informal         leisure    neutral     medium    familiar
# ...              ...             ...        ...        ...         ...
# 1267         neutral  home furniture    neutral       hard  unfamiliar
# 1268         neutral         clothes    neutral       easy    familiar
# 1269  slang/informal      automobile    neutral       hard    familiar
# 1270         neutral      literature    neutral     medium  unfamiliar
# 1271         neutral       education    neutral     medium  unfamiliar
#
#       question_  ... If so, what were the issues?  \
# 0            74  ...                          NaN
# 1            74  ...                          NaN
# 2            74  ...                          NaN
# 3            74  ...                          NaN
# 4            74  ...                          NaN
# ...         ...  ...                          ...
# 1267          1  ...                          NaN
# 1268         17  ...                          NaN
# 1269         54  ...                          NaN
# 1270         22  ...                          NaN
# 1271         46  ...                          NaN
#
#      Did you feel you had enough time to complete the assessment in one sitting?  \
# 0                                                   yes
# 1                                                   NaN
# 2                                                   yes
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      If so, did you feel pressured for time? Please share your thoughts and experience.  \
# 0     I did not feel pressured for time, the timer l...
# 1                                                   NaN
# 2         I had enough time and didn't feel pressured .
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Did you feel there was a good range of difficulty in the questions?  \
# 0                                                   yes
# 1                                                   NaN
# 2                                                   yes
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Please explain your thoughts? Any details you can offer are greatly appreciated.  \
# 0     there were questions for every language levels...
# 1                                                   NaN
# 2     Items weren't so easy so it was a bit challeng...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#       Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
# 0                                                   yes
# 1                                                   NaN
# 2                                                   yes
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      If so, please list what you used, and explain why you chose to use them?  \
# 0     I had to look up a word on google because I wa...
# 1                                                   NaN
# 2     I used Google search and Linguee  for mutiple ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
# 0                                                    no
# 1                                                   NaN
# 2                                                    no
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#       If so, any information you can provide is helpful.  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#                               Tenure
# 0                           90+ days
# 1                           90+ days
# 2                           90+ days
# 3                           90+ days
# 4                           90+ days
# ...                              ...
# 1267  Google Translate Control Group
# 1268  Google Translate Control Group
# 1269  Google Translate Control Group
# 1270  Google Translate Control Group
# 1271  Google Translate Control Group
#
# [1272 rows x 46 columns]

# %%
pilot_var_selected
# Out:
# 'Pilot 1A-1B'

# %%
rcR
# Out:
#     Language         _id question_no_1 question_no_2 question_no_3  \
# 0     French  5700206236             c             a             a
# 1     French  5700215923             c             a             a
# 2     French  5700345459             c             a             a
# 3     French  5700581103             c             a             a
# 4     French  5700977804             c             a             a
# ..       ...         ...           ...           ...           ...
# 123   French  5713289134             b             c             a
# 124   French  5713332465             c             a             a
# 125   French  5713341018             c             c             a
# 126   French  5713348682             c             b             c
# 127   French  5713353413             b             c             a
#
#      question_no_4  question_no_5  \
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
# ..             ...            ...
# 123            NaN            NaN
# 124            NaN            NaN
# 125            NaN            NaN
# 126            NaN            NaN
# 127            NaN            NaN
#
#                                                changes       complexity  \
# 0                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 1                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 2                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 3                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 4                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# ..                                                 ...              ...
# 123  Added/removed a couple of words to make the pa...  straightforward
# 124                 Fixed typo, Lagarfeld -> Lagerfeld  straightforward
# 125                                                NaN          complex
# 126  Shortened the text by removing several phrases...          complex
# 127  Added/removed a couple of words to make the pa...  straightforward
#
#     familiarity  ...  \
# 0      familiar  ...
# 1      familiar  ...
# 2      familiar  ...
# 3      familiar  ...
# 4      familiar  ...
# ..          ...  ...
# 123  unfamiliar  ...
# 124    familiar  ...
# 125    familiar  ...
# 126  unfamiliar  ...
# 127  unfamiliar  ...
#
#     If so, did you feel pressured for time? Please share your thoughts and experience.  \
# 0    I did not feel pressured for time, the timer l...
# 1                                                  NaN
# 2        I had enough time and didn't feel pressured .
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     Did you feel there was a good range of difficulty in the questions?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     Please explain your thoughts? Any details you can offer are greatly appreciated.  \
# 0    there were questions for every language levels...
# 1                                                  NaN
# 2    Items weren't so easy so it was a bit challeng...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     If so, please list what you used, and explain why you chose to use them?  \
# 0    I had to look up a word on google because I wa...
# 1                                                  NaN
# 2    I used Google search and Linguee  for mutiple ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
# 0                                                   no
# 1                                                  NaN
# 2                                                   no
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#     If so, any information you can provide is helpful.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
#
#                              Tenure Time_Taken_Seconds  \
# 0                          90+ days                313
# 1                          90+ days                149
# 2                          90+ days                247
# 3                          90+ days                113
# 4                          90+ days                154
# ..                              ...                ...
# 123  Google Translate Control Group                170
# 124  Google Translate Control Group                257
# 125  Google Translate Control Group                292
# 126  Google Translate Control Group                255
# 127  Google Translate Control Group                165
#
#     Time_Taken_Minutes_Overall
# 0                    22.300000
# 1                    11.850000
# 2                    17.516667
# 3                    11.816667
# 4                    14.300000
# ..                         ...
# 123                   8.266667
# 124                  16.150000
# 125                  16.150000
# 126                  16.150000
# 127                  16.150000
#
# [128 rows x 94 columns]

# %%
v1R
# Out:
#     Language         _id rater_answer            a_domain      a_register  \
# 0     French  5700185097          yes            shopping         neutral
# 1     French  5700196181          yes            shopping         neutral
# 2     French  5700332590          yes            shopping         neutral
# 3     French  5700566722           no            shopping         neutral
# 4     French  5700963570          yes            shopping         neutral
# ..       ...         ...          ...                 ...             ...
# 624   French  5713221393          yes               books         neutral
# 625   French  5713228977          yes             science       technical
# 626   French  5713229927           no  general vocabulary         neutral
# 627   French  5713230801          yes  general vocabulary  slang/informal
# 628   French  5713231418          yes  general vocabulary          formal
#
#                b_domain      b_register difficulty familiarity  question_  \
# 0              shopping         neutral       easy    familiar         23
# 1              shopping         neutral       easy    familiar         23
# 2              shopping         neutral       easy    familiar         23
# 3              shopping         neutral       easy    familiar         23
# 4              shopping         neutral       easy    familiar         23
# ..                  ...             ...        ...         ...        ...
# 624               books          formal     medium    familiar          4
# 625             science       technical       hard  unfamiliar         15
# 626  general vocabulary         neutral       hard    familiar         37
# 627  general vocabulary  slang/informal     medium  unfamiliar         21
# 628  general vocabulary          formal     medium    familiar         31
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 624  ...
# 625  ...
# 626  ...
# 627  ...
# 628  ...
#
#     If so, did you feel pressured for time? Please share your thoughts and experience.  \
# 0    I did not feel pressured for time, the timer l...
# 1                                                  NaN
# 2        I had enough time and didn't feel pressured .
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     Did you feel there was a good range of difficulty in the questions?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     Please explain your thoughts? Any details you can offer are greatly appreciated.  \
# 0    there were questions for every language levels...
# 1                                                  NaN
# 2    Items weren't so easy so it was a bit challeng...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
# 0                                                  yes
# 1                                                  NaN
# 2                                                  yes
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     If so, please list what you used, and explain why you chose to use them?  \
# 0    I had to look up a word on google because I wa...
# 1                                                  NaN
# 2    I used Google search and Linguee  for mutiple ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#      If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
# 0                                                   no
# 1                                                  NaN
# 2                                                   no
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#     If so, any information you can provide is helpful.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                NaN
# 628                                                NaN
#
#                              Tenure  Time_Taken_Seconds  \
# 0                          90+ days                  16
# 1                          90+ days                  43
# 2                          90+ days                  22
# 3                          90+ days                  12
# 4                          90+ days                  24
# ..                              ...                 ...
# 624  Google Translate Control Group                  13
# 625  Google Translate Control Group                  10
# 626  Google Translate Control Group                  28
# 627  Google Translate Control Group                  21
# 628  Google Translate Control Group                  16
#
#     Time_Taken_Minutes_Overall
# 0                     2.800000
# 1                     8.233333
# 2                     6.783333
# 3                     1.116667
# 4                     3.250000
# ..                         ...
# 624                   7.533333
# 625                   7.533333
# 626                   7.533333
# 627                   7.533333
# 628                   7.533333
#
# [629 rows x 48 columns]

# %%
v2R
# Out:
#      Language         _id                   rater_answer        a_domain  \
# 0      French  5700186158  a_and_b_have_the_same_meaning         leisure
# 1      French  5700200727      b_is_more_specific_than_a         leisure
# 2      French  5700335878            a_and_b_are_related         leisure
# 3      French  5700390611            a_and_b_are_related         leisure
# 4      French  5700567781            a_and_b_are_related         leisure
# ...       ...         ...                            ...             ...
# 1267   French  5713305896        a_and_b_are_not_related  home furniture
# 1268   French  5713306680        a_and_b_are_not_related         clothes
# 1269   French  5713307377      b_is_more_specific_than_a      automobile
# 1270   French  5713308509        a_and_b_are_not_related      literature
# 1271   French  5713309316      a_is_more_specific_than_b       education
#
#           a_register        b_domain b_register difficulty familiarity  \
# 0     slang/informal         leisure    neutral     medium    familiar
# 1     slang/informal         leisure    neutral     medium    familiar
# 2     slang/informal         leisure    neutral     medium    familiar
# 3     slang/informal         leisure    neutral     medium    familiar
# 4     slang/informal         leisure    neutral     medium    familiar
# ...              ...             ...        ...        ...         ...
# 1267         neutral  home furniture    neutral       hard  unfamiliar
# 1268         neutral         clothes    neutral       easy    familiar
# 1269  slang/informal      automobile    neutral       hard    familiar
# 1270         neutral      literature    neutral     medium  unfamiliar
# 1271         neutral       education    neutral     medium  unfamiliar
#
#       question_  ...  \
# 0            74  ...
# 1            74  ...
# 2            74  ...
# 3            74  ...
# 4            74  ...
# ...         ...  ...
# 1267          1  ...
# 1268         17  ...
# 1269         54  ...
# 1270         22  ...
# 1271         46  ...
#
#      If so, did you feel pressured for time? Please share your thoughts and experience.  \
# 0     I did not feel pressured for time, the timer l...
# 1                                                   NaN
# 2         I had enough time and didn't feel pressured .
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Did you feel there was a good range of difficulty in the questions?  \
# 0                                                   yes
# 1                                                   NaN
# 2                                                   yes
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Please explain your thoughts? Any details you can offer are greatly appreciated.  \
# 0     there were questions for every language levels...
# 1                                                   NaN
# 2     Items weren't so easy so it was a bit challeng...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
# 0                                                   yes
# 1                                                   NaN
# 2                                                   yes
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      If so, please list what you used, and explain why you chose to use them?  \
# 0     I had to look up a word on google because I wa...
# 1                                                   NaN
# 2     I used Google search and Linguee  for mutiple ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#       If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
# 0                                                    no
# 1                                                   NaN
# 2                                                    no
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#      If so, any information you can provide is helpful.  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1267                                                NaN
# 1268                                                NaN
# 1269                                                NaN
# 1270                                                NaN
# 1271                                                NaN
#
#                               Tenure  Time_Taken_Seconds  \
# 0                           90+ days                  66
# 1                           90+ days                 101
# 2                           90+ days                  11
# 3                           90+ days                  16
# 4                           90+ days                  38
# ...                              ...                 ...
# 1267  Google Translate Control Group                  27
# 1268  Google Translate Control Group                  21
# 1269  Google Translate Control Group                  22
# 1270  Google Translate Control Group                  31
# 1271  Google Translate Control Group                  17
#
#      Time_Taken_Minutes_Overall
# 0                     31.983333
# 1                     23.500000
# 2                     20.066667
# 3                      0.700000
# 4                     16.583333
# ...                         ...
# 1267                  19.333333
# 1268                  19.333333
# 1269                  19.333333
# 1270                  19.333333
# 1271                  19.333333
#
# [1272 rows x 48 columns]

# %%
list_of_datasets['RC with Answers']
# Out:
#    Language          Fluency                          Tenure    _unit_id  \
# 0    French           Fluent                     1 - 90 days  2809649914
# 1    French           Fluent                     1 - 90 days  2809649914
# 2    French           Fluent                     1 - 90 days  2809649914
# 3    French           Fluent                     1 - 90 days  2809649915
# 4    French           Fluent                     1 - 90 days  2809649915
# 5    French           Fluent                     1 - 90 days  2809649915
# 6    French           Fluent                     1 - 90 days  2809649915
# 7    French           Fluent                     1 - 90 days  2809649916
# 8    French           Fluent                     1 - 90 days  2809649916
# 9    French           Fluent                     1 - 90 days  2809649916
# 10   French           Fluent                     1 - 90 days  2809649916
# 11   French           Fluent                     1 - 90 days  2809649917
# 12   French           Fluent                     1 - 90 days  2809649917
# 13   French           Fluent                        90+ days  2809649914
# 14   French           Fluent                        90+ days  2809649915
# 15   French           Fluent                        90+ days  2809649915
# 16   French           Fluent                        90+ days  2809649916
# 17   French           Fluent                        90+ days  2809649916
# 18   French           Fluent                        90+ days  2809649917
# 19   French               GT  Google Translate Control Group  2809649914
# 20   French               GT  Google Translate Control Group  2809649914
# 21   French               GT  Google Translate Control Group  2809649915
# 22   French               GT  Google Translate Control Group  2809649915
# 23   French               GT  Google Translate Control Group  2809649915
# 24   French               GT  Google Translate Control Group  2809649915
# 25   French               GT  Google Translate Control Group  2809649916
# 26   French               GT  Google Translate Control Group  2809649916
# 27   French               GT  Google Translate Control Group  2809649916
# 28   French     Intermediate                     1 - 90 days  2809649915
# 29   French     Intermediate                     1 - 90 days  2809649916
# 30   French     Intermediate                     1 - 90 days  2809649916
# 31   French     Intermediate                     1 - 90 days  2809649916
# 32   French  Not Categorized                     1 - 90 days  2809649916
# 33   French  Not Categorized                     1 - 90 days  2809649916
#
#                                                 title aa ra  a           q  \
# 0               20 Françaises que le monde nous envie  c  a  0  Question 1
# 1               20 Françaises que le monde nous envie  a  b  0  Question 2
# 2               20 Françaises que le monde nous envie  a  c  0  Question 3
# 3   Daredevil: pourquoi un éventuel retour de la s...  b  c  0  Question 1
# 4   Daredevil: pourquoi un éventuel retour de la s...  b  c  0  Question 2
# 5   Daredevil: pourquoi un éventuel retour de la s...  b  a  0  Question 2
# 6   Daredevil: pourquoi un éventuel retour de la s...  c  a  0  Question 3
# 7   Du peintre au restaurateur. Histoire d'un tabl...  b  a  0  Question 1
# 8   Du peintre au restaurateur. Histoire d'un tabl...  a  b  0  Question 2
# 9   Du peintre au restaurateur. Histoire d'un tabl...  a  c  0  Question 2
# 10  Du peintre au restaurateur. Histoire d'un tabl...  c  a  0  Question 3
# 11  Django Reinhardt : 10 (petites) choses que vou...  b  c  0  Question 1
# 12  Django Reinhardt : 10 (petites) choses que vou...  c  a  0  Question 2
# 13              20 Françaises que le monde nous envie  c  a  0  Question 1
# 14  Daredevil: pourquoi un éventuel retour de la s...  b  a  0  Question 1
# 15  Daredevil: pourquoi un éventuel retour de la s...  c  a  0  Question 3
# 16  Du peintre au restaurateur. Histoire d'un tabl...  a  b  0  Question 2
# 17  Du peintre au restaurateur. Histoire d'un tabl...  a  c  0  Question 2
# 18  Django Reinhardt : 10 (petites) choses que vou...  b  c  0  Question 1
# 19              20 Françaises que le monde nous envie  c  a  0  Question 1
# 20              20 Françaises que le monde nous envie  a  b  0  Question 2
# 21  Daredevil: pourquoi un éventuel retour de la s...  b  a  0  Question 1
# 22  Daredevil: pourquoi un éventuel retour de la s...  b  c  0  Question 1
# 23  Daredevil: pourquoi un éventuel retour de la s...  b  c  0  Question 2
# 24  Daredevil: pourquoi un éventuel retour de la s...  c  a  0  Question 3
# 25  Du peintre au restaurateur. Histoire d'un tabl...  b  c  0  Question 1
# 26  Du peintre au restaurateur. Histoire d'un tabl...  a  b  0  Question 2
# 27  Du peintre au restaurateur. Histoire d'un tabl...  c  a  0  Question 3
# 28  Daredevil: pourquoi un éventuel retour de la s...  b  c  0  Question 2
# 29  Du peintre au restaurateur. Histoire d'un tabl...  b  a  0  Question 1
# 30  Du peintre au restaurateur. Histoire d'un tabl...  a  b  0  Question 2
# 31  Du peintre au restaurateur. Histoire d'un tabl...  c  a  0  Question 3
# 32  Du peintre au restaurateur. Histoire d'un tabl...  a  b  0  Question 2
# 33  Du peintre au restaurateur. Histoire d'un tabl...  a  c  0  Question 2
#
#          d   register                                         skill  Count  \
# 0     easy   informal    initial understanding: finding key details      1
# 1   medium   informal  initial understanding: finding the main idea      3
# 2     easy   informal                 synthesis and decision-making      1
# 3     easy     formal    initial understanding: finding key details      7
# 4   medium     formal                 synthesis and decision-making      3
# 5   medium     formal                 synthesis and decision-making      1
# 6     hard     formal                 synthesis and decision-making      4
# 7   medium  technical    initial understanding: finding key details      7
# 8     hard  technical                 synthesis and decision-making      5
# 9     hard  technical                 synthesis and decision-making      2
# 10    hard  technical                 synthesis and decision-making      1
# 11    easy    neutral    initial understanding: finding key details      1
# 12  medium    neutral                 synthesis and decision-making      2
# 13    easy   informal    initial understanding: finding key details      1
# 14    easy     formal    initial understanding: finding key details      2
# 15    hard     formal                 synthesis and decision-making      3
# 16    hard  technical                 synthesis and decision-making      4
# 17    hard  technical                 synthesis and decision-making      1
# 18    easy    neutral    initial understanding: finding key details      2
# 19    easy   informal    initial understanding: finding key details      1
# 20  medium   informal  initial understanding: finding the main idea      1
# 21    easy     formal    initial understanding: finding key details      1
# 22    easy     formal    initial understanding: finding key details      1
# 23  medium     formal                 synthesis and decision-making      1
# 24    hard     formal                 synthesis and decision-making      2
# 25  medium  technical    initial understanding: finding key details      1
# 26    hard  technical                 synthesis and decision-making      2
# 27    hard  technical                 synthesis and decision-making      1
# 28  medium     formal                 synthesis and decision-making      1
# 29  medium  technical    initial understanding: finding key details      1
# 30    hard  technical                 synthesis and decision-making      1
# 31    hard  technical                 synthesis and decision-making      1
# 32    hard  technical                 synthesis and decision-making      1
# 33    hard  technical                 synthesis and decision-making      1
#
#     Total  Fail_Rate
# 0      16       0.06
# 1      16       0.19
# 2      16       0.06
# 3      16       0.44
# 4      16       0.19
# 5      16       0.06
# 6      16       0.25
# 7      16       0.44
# 8      16       0.31
# 9      16       0.12
# 10     16       0.06
# 11     16       0.06
# 12     16       0.12
# 13      8       0.12
# 14      8       0.25
# 15      8       0.38
# 16      8       0.50
# 17      8       0.12
# 18      8       0.25
# 19      2       0.50
# 20      2       0.50
# 21      2       0.50
# 22      2       0.50
# 23      2       0.50
# 24      2       1.00
# 25      2       0.50
# 26      2       1.00
# 27      2       0.50
# 28      3       0.33
# 29      3       0.33
# 30      3       0.33
# 31      3       0.33
# 32      2       0.50
# 33      2       0.50

# %%
list_of_summaries
# Out:
# {'Pilot 1_rc':     Language         _id question_no_1 question_no_2 question_no_3  \
#  0     French  5700206236             c             a             a
#  1     French  5700215923             c             a             a
#  2     French  5700345459             c             a             a
#  3     French  5700581103             c             a             a
#  4     French  5700977804             c             a             a
#  ..       ...         ...           ...           ...           ...
#  123   French  5713289134             b             c             a
#  124   French  5713332465             c             a             a
#  125   French  5713341018             c             c             a
#  126   French  5713348682             c             b             c
#  127   French  5713353413             b             c             a
#
#       question_no_4  question_no_5  \
#  0              NaN            NaN
#  1              NaN            NaN
#  2              NaN            NaN
#  3              NaN            NaN
#  4              NaN            NaN
#  ..             ...            ...
#  123            NaN            NaN
#  124            NaN            NaN
#  125            NaN            NaN
#  126            NaN            NaN
#  127            NaN            NaN
#
#                                                 changes       complexity  \
#  0                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
#  1                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
#  2                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
#  3                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
#  4                   Fixed typo, Lagarfeld -> Lagerfeld  straightforward
#  ..                                                 ...              ...
#  123  Added/removed a couple of words to make the pa...  straightforward
#  124                 Fixed typo, Lagarfeld -> Lagerfeld  straightforward
#  125                                                NaN          complex
#  126  Shortened the text by removing several phrases...          complex
#  127  Added/removed a couple of words to make the pa...  straightforward
#
#      familiarity  ... If so, what were the issues?  \
#  0      familiar  ...                          NaN
#  1      familiar  ...                          NaN
#  2      familiar  ...                          NaN
#  3      familiar  ...                          NaN
#  4      familiar  ...                          NaN
#  ..          ...  ...                          ...
#  123  unfamiliar  ...                          NaN
#  124    familiar  ...                          NaN
#  125    familiar  ...                          NaN
#  126  unfamiliar  ...                          NaN
#  127  unfamiliar  ...                          NaN
#
#      Did you feel you had enough time to complete the assessment in one sitting?  \
#  0                                                  yes
#  1                                                  NaN
#  2                                                  yes
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#      If so, did you feel pressured for time? Please share your thoughts and experience.  \
#  0    I did not feel pressured for time, the timer l...
#  1                                                  NaN
#  2        I had enough time and didn't feel pressured .
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#      Did you feel there was a good range of difficulty in the questions?  \
#  0                                                  yes
#  1                                                  NaN
#  2                                                  yes
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#      Please explain your thoughts? Any details you can offer are greatly appreciated.  \
#  0    there were questions for every language levels...
#  1                                                  NaN
#  2    Items weren't so easy so it was a bit challeng...
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#      Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
#  0                                                  yes
#  1                                                  NaN
#  2                                                  yes
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#      If so, please list what you used, and explain why you chose to use them?  \
#  0    I had to look up a word on google because I wa...
#  1                                                  NaN
#  2    I used Google search and Linguee  for mutiple ...
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#      If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
#  0                                                   no
#  1                                                  NaN
#  2                                                   no
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#      If so, any information you can provide is helpful.  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  123                                                NaN
#  124                                                NaN
#  125                                                NaN
#  126                                                NaN
#  127                                                NaN
#
#                               Tenure
#  0                          90+ days
#  1                          90+ days
#  2                          90+ days
#  3                          90+ days
#  4                          90+ days
#  ..                              ...
#  123  Google Translate Control Group
#  124  Google Translate Control Group
#  125  Google Translate Control Group
#  126  Google Translate Control Group
#  127  Google Translate Control Group
#
#  [128 rows x 92 columns],
#  'Pilot 1_v1':     Language         _id rater_answer            a_domain      a_register  \
#  0     French  5700185097          yes            shopping         neutral
#  1     French  5700196181          yes            shopping         neutral
#  2     French  5700332590          yes            shopping         neutral
#  3     French  5700566722           no            shopping         neutral
#  4     French  5700963570          yes            shopping         neutral
#  ..       ...         ...          ...                 ...             ...
#  624   French  5713221393          yes               books         neutral
#  625   French  5713228977          yes             science       technical
#  626   French  5713229927           no  general vocabulary         neutral
#  627   French  5713230801          yes  general vocabulary  slang/informal
#  628   French  5713231418          yes  general vocabulary          formal
#
#                 b_domain      b_register difficulty familiarity  question_  \
#  0              shopping         neutral       easy    familiar         23
#  1              shopping         neutral       easy    familiar         23
#  2              shopping         neutral       easy    familiar         23
#  3              shopping         neutral       easy    familiar         23
#  4              shopping         neutral       easy    familiar         23
#  ..                  ...             ...        ...         ...        ...
#  624               books          formal     medium    familiar          4
#  625             science       technical       hard  unfamiliar         15
#  626  general vocabulary         neutral       hard    familiar         37
#  627  general vocabulary  slang/informal     medium  unfamiliar         21
#  628  general vocabulary          formal     medium    familiar         31
#
#       ... If so, what were the issues?  \
#  0    ...                          NaN
#  1    ...                          NaN
#  2    ...                          NaN
#  3    ...                          NaN
#  4    ...                          NaN
#  ..   ...                          ...
#  624  ...                          NaN
#  625  ...                          NaN
#  626  ...                          NaN
#  627  ...                          NaN
#  628  ...                          NaN
#
#      Did you feel you had enough time to complete the assessment in one sitting?  \
#  0                                                  yes
#  1                                                  NaN
#  2                                                  yes
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#      If so, did you feel pressured for time? Please share your thoughts and experience.  \
#  0    I did not feel pressured for time, the timer l...
#  1                                                  NaN
#  2        I had enough time and didn't feel pressured .
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#      Did you feel there was a good range of difficulty in the questions?  \
#  0                                                  yes
#  1                                                  NaN
#  2                                                  yes
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#      Please explain your thoughts? Any details you can offer are greatly appreciated.  \
#  0    there were questions for every language levels...
#  1                                                  NaN
#  2    Items weren't so easy so it was a bit challeng...
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#       Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
#  0                                                  yes
#  1                                                  NaN
#  2                                                  yes
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#      If so, please list what you used, and explain why you chose to use them?  \
#  0    I had to look up a word on google because I wa...
#  1                                                  NaN
#  2    I used Google search and Linguee  for mutiple ...
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#      If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
#  0                                                   no
#  1                                                  NaN
#  2                                                   no
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#       If so, any information you can provide is helpful.  \
#  0                                                  NaN
#  1                                                  NaN
#  2                                                  NaN
#  3                                                  NaN
#  4                                                  NaN
#  ..                                                 ...
#  624                                                NaN
#  625                                                NaN
#  626                                                NaN
#  627                                                NaN
#  628                                                NaN
#
#                               Tenure
#  0                          90+ days
#  1                          90+ days
#  2                          90+ days
#  3                          90+ days
#  4                          90+ days
#  ..                              ...
#  624  Google Translate Control Group
#  625  Google Translate Control Group
#  626  Google Translate Control Group
#  627  Google Translate Control Group
#  628  Google Translate Control Group
#
#  [629 rows x 46 columns],
#  'Pilot 1_v2':      Language         _id                   rater_answer        a_domain  \
#  0      French  5700186158  a_and_b_have_the_same_meaning         leisure
#  1      French  5700200727      b_is_more_specific_than_a         leisure
#  2      French  5700335878            a_and_b_are_related         leisure
#  3      French  5700390611            a_and_b_are_related         leisure
#  4      French  5700567781            a_and_b_are_related         leisure
#  ...       ...         ...                            ...             ...
#  1267   French  5713305896        a_and_b_are_not_related  home furniture
#  1268   French  5713306680        a_and_b_are_not_related         clothes
#  1269   French  5713307377      b_is_more_specific_than_a      automobile
#  1270   French  5713308509        a_and_b_are_not_related      literature
#  1271   French  5713309316      a_is_more_specific_than_b       education
#
#            a_register        b_domain b_register difficulty familiarity  \
#  0     slang/informal         leisure    neutral     medium    familiar
#  1     slang/informal         leisure    neutral     medium    familiar
#  2     slang/informal         leisure    neutral     medium    familiar
#  3     slang/informal         leisure    neutral     medium    familiar
#  4     slang/informal         leisure    neutral     medium    familiar
#  ...              ...             ...        ...        ...         ...
#  1267         neutral  home furniture    neutral       hard  unfamiliar
#  1268         neutral         clothes    neutral       easy    familiar
#  1269  slang/informal      automobile    neutral       hard    familiar
#  1270         neutral      literature    neutral     medium  unfamiliar
#  1271         neutral       education    neutral     medium  unfamiliar
#
#        question_  ... If so, what were the issues?  \
#  0            74  ...                          NaN
#  1            74  ...                          NaN
#  2            74  ...                          NaN
#  3            74  ...                          NaN
#  4            74  ...                          NaN
#  ...         ...  ...                          ...
#  1267          1  ...                          NaN
#  1268         17  ...                          NaN
#  1269         54  ...                          NaN
#  1270         22  ...                          NaN
#  1271         46  ...                          NaN
#
#       Did you feel you had enough time to complete the assessment in one sitting?  \
#  0                                                   yes
#  1                                                   NaN
#  2                                                   yes
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#       If so, did you feel pressured for time? Please share your thoughts and experience.  \
#  0     I did not feel pressured for time, the timer l...
#  1                                                   NaN
#  2         I had enough time and didn't feel pressured .
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#       Did you feel there was a good range of difficulty in the questions?  \
#  0                                                   yes
#  1                                                   NaN
#  2                                                   yes
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#       Please explain your thoughts? Any details you can offer are greatly appreciated.  \
#  0     there were questions for every language levels...
#  1                                                   NaN
#  2     Items weren't so easy so it was a bit challeng...
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#        Did you use Google search / Google Translate / Word Reference / Linguee / any other sources to help you complete the test?  \
#  0                                                   yes
#  1                                                   NaN
#  2                                                   yes
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#       If so, please list what you used, and explain why you chose to use them?  \
#  0     I had to look up a word on google because I wa...
#  1                                                   NaN
#  2     I used Google search and Linguee  for mutiple ...
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#       If you did not finish the full assessment, we would love to know why. Did you find it too time consuming? Did you get interrupted?  \
#  0                                                    no
#  1                                                   NaN
#  2                                                    no
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#        If so, any information you can provide is helpful.  \
#  0                                                   NaN
#  1                                                   NaN
#  2                                                   NaN
#  3                                                   NaN
#  4                                                   NaN
#  ...                                                 ...
#  1267                                                NaN
#  1268                                                NaN
#  1269                                                NaN
#  1270                                                NaN
#  1271                                                NaN
#
#                                Tenure
#  0                           90+ days
#  1                           90+ days
#  2                           90+ days
#  3                           90+ days
#  4                           90+ days
#  ...                              ...
#  1267  Google Translate Control Group
#  1268  Google Translate Control Group
#  1269  Google Translate Control Group
#  1270  Google Translate Control Group
#  1271  Google Translate Control Group
#
#  [1272 rows x 46 columns]}
