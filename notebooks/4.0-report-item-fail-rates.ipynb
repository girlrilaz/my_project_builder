# %%
# %reset

# %% [markdown]
# ###################################################################
# #Script Name    :
# #Description    :
# #Args           :
# #Author         : Nikhil Rao in R, converted to Python by Nor Raymond
# #Email          : nraymond@appen.com
# ###################################################################

# %%
import os
import glob 
import pandas as pd
import numpy as np
import yaml
import warnings
warnings.filterwarnings("ignore")

# Function to load yaml configuration file
def load_config(config_name):
    with open(os.path.join(config_path, config_name), 'r') as file:
        config = yaml.safe_load(file)

    return config

config_path = "conf/base"

try:
    
    # load yaml catalog configuration file
    config = load_config("catalog.yml")

    os.chdir(config["project_path"])
    root_path = os.getcwd()
    
except:
    
    os.chdir('..')
    # load yaml catalog configuration file
    config = load_config("catalog.yml")

    os.chdir(config["project_path"])
    root_path = os.getcwd()
    
# import data_processing module
import src.data.data_processing as data_processing

# %%
# import data from data_processing module
raters, r1, r2, r3, languages, rc, v1, v2 = data_processing.main()
languages
# Out:
#               Language
# 0              Russian
# 1               Hebrew
# 2           Indonesian
# 3  Chinese(Simplified)

# %%
def language_selection(languages):

    while True:
        try:
            language_index = int(input("\nPlease select the number of the Language you are assessing: "))
            if language_index < min(languages.index) or language_index > max(languages.index):
                print(f"\nYou must enter numbers between {min(languages.index)} - {max(languages.index)}... Please try again")
                continue
            elif language_index == "":
                print("\nYou must enter any numbers")
                continue
            else:
                print(f"\nYou have selected {language_index} for {languages.iloc[language_index, 0]}")
                language_selected = languages.iloc[language_index, 0]
                break

        except ValueError:
            print(f"\nYou must enter numerical values only... Please try again")
            continue
        else:
            break
            
    return language_selected
    
language_selected = language_selection(languages)
# Out:
# Please select the number of the Language you are assessing:  1
# You have selected 1 for Hebrew

# %% [markdown]
# #### Functions for Language Modification - getting the overall time taken

# %%
# function for Language Modification
def get_time_taken(df, language_selected):

    # Filter data based on selected language
    dfr = df[df['Language'] == language_selected]

    # Time Taken by Item
    dfr["Time_Taken_Seconds"] = (dfr['_created_at'] - dfr['_started_at']).dt.seconds

    # Time Taken Overall
    dfr_grouped = dfr.groupby('_worker_id').sum('Time_Taken_Seconds')
    dfr_grouped["Time_Taken_Minutes_Overall"] = dfr_grouped["Time_Taken_Seconds"] / 60
    dfr_grouped = dfr_grouped.reset_index()
    dfr = pd.merge(dfr, dfr_grouped[["Time_Taken_Minutes_Overall", "_worker_id"]], how = 'left', on = '_worker_id')

    return dfr

def get_time_taken_all(language_selected, rc, v1, v2):
    
    df_list = [rc, v1, v2]
    keys = ["rcR", "v1R", "v2R"]
    df_time = {}
    
    for df, key in zip(df_list, keys) :

        dfr = get_time_taken(df, language_selected)
        df_time[key] = dfr

    rcR, v1R, v2R = df_time["rcR"], df_time["v1R"], df_time["v2R"]    
    
    return rcR, v1R, v2R

rcR, v1R, v2R = get_time_taken_all(language_selected, rc, v1, v2)

# %% [markdown]
# #### Functions for calculating Fail Rates

# %%
# # V1 Fail Rates -----------------------------------------------------------
# v1_actual_correct_by_question <- v1R %>%
#   ## Remove Tenure from Grouping
#   dplyr::select(Language, Market, `_worker_id`, `_unit_id`, question_, a_domain, a_register, wordphrase_a, b_domain, b_register, wordphrase_b, 
#                 difficulty, Answer, Score) %>%
#   group_by(Language, Market, `_unit_id`, question_, a_domain, a_register, wordphrase_a, b_domain, b_register, wordphrase_b, 
#            difficulty, Answer, Score) %>%
#   summarise(Count_of_Test_Takers = n()) %>% 
#   ungroup() %>%
#   group_by(Language, Market, `_unit_id`, question_, a_domain, a_register, wordphrase_a, b_domain, b_register, wordphrase_b, difficulty) %>% 
#   mutate(Total_Test_Takers = sum(Count_of_Test_Takers),
#          Fail_Rate = round((Count_of_Test_Takers / Total_Test_Takers), 2)) %>% 
#   ungroup() %>% 
#   group_by(Market, `_unit_id`, question_, a_domain, a_register, wordphrase_a, b_domain, b_register, wordphrase_b, difficulty) %>%
#   filter(Score %in% "0") %>%
#   ungroup() %>% 
#   arrange(Market, -Fail_Rate)

# %%
def v1_actual_correct_by_question(v1R):
    
    v1R_temp = v1R[['Language', 'Market', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 
                    'wordphrase_a', 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score']]

    v1R_grouped = v1R_temp.groupby(['Language', 'Market', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score'])['_worker_id'].count().reset_index()
    v1R_grouped = v1R_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
    
    v1R_grouped["Total_Test_Takers"] = v1R_grouped.groupby(['Language', 'Market', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                    'b_domain', 'b_register', 'wordphrase_b', 'difficulty'])["Count_of_Test_Takers"].transform('sum')   
    
    return v1R_grouped

v1R_grouped = v1_actual_correct_by_question(v1R)
v1R_grouped
# Out:
#    Language Market    _unit_id  question_       a_domain      a_register  \
# 0    Hebrew  IW-IW  2920269741          3           Mood          formal
# 1    Hebrew  IW-IW  2920269741          3           Mood          formal
# 2    Hebrew  IW-IW  2920269742          4       Shopping  slang/informal
# 3    Hebrew  IW-IW  2920269742          4       Shopping  slang/informal
# 4    Hebrew  IW-IW  2920269743          5        Finance  slang/informal
# 5    Hebrew  IW-IW  2920269743          5        Finance  slang/informal
# 6    Hebrew  IW-IW  2920269744          6           Food         neutral
# 7    Hebrew  IW-IW  2920269744          6           Food         neutral
# 8    Hebrew  IW-IW  2920269745          9     Restaurant          formal
# 9    Hebrew  IW-IW  2920269745          9     Restaurant          formal
# 10   Hebrew  IW-IW  2920269746         11     Body parts         neutral
# 11   Hebrew  IW-IW  2920269746         11     Body parts         neutral
# 12   Hebrew  IW-IW  2920269747         13     Literature          formal
# 13   Hebrew  IW-IW  2920269747         13     Literature          formal
# 14   Hebrew  IW-IW  2920269748         14     Situations  slang/informal
# 15   Hebrew  IW-IW  2920269748         14     Situations  slang/informal
# 16   Hebrew  IW-IW  2920269749         15        Hygiene  slang/informal
# 17   Hebrew  IW-IW  2920269749         15        Hygiene  slang/informal
# 18   Hebrew  IW-IW  2920269750         20        Biology         neutral
# 19   Hebrew  IW-IW  2920269750         20        Biology         neutral
# 20   Hebrew  IW-IW  2920269751         21     Appliances  slang/informal
# 21   Hebrew  IW-IW  2920269751         21     Appliances  slang/informal
# 22   Hebrew  IW-IW  2920269752         23      Chemistry       technical
# 23   Hebrew  IW-IW  2920269752         23      Chemistry       technical
# 24   Hebrew  IW-IW  2920269753         26        General       technical
# 25   Hebrew  IW-IW  2920269753         26        General       technical
# 26   Hebrew  IW-IW  2920269754         27      Emotional          formal
# 27   Hebrew  IW-IW  2920269754         27      Emotional          formal
# 28   Hebrew  IW-IW  2920269755         30      Emotional  slang/informal
# 29   Hebrew  IW-IW  2920269755         30      Emotional  slang/informal
# 30   Hebrew  IW-IW  2920269756         31        General         neutral
# 31   Hebrew  IW-IW  2920269756         31        General         neutral
# 32   Hebrew  IW-IW  2920269757         37  Entertainment       technical
# 33   Hebrew  IW-IW  2920269757         37  Entertainment       technical
# 34   Hebrew  IW-IW  2920269758         38    Accessories         neutral
# 35   Hebrew  IW-IW  2920269758         38    Accessories         neutral
# 36   Hebrew  IW-IW  2920269759         39        Biology         neutral
# 37   Hebrew  IW-IW  2920269759         39        Biology         neutral
# 38   Hebrew  IW-IW  2920269760         40       Location         neutral
# 39   Hebrew  IW-IW  2920269760         40       Location         neutral
#
#    wordphrase_a       b_domain      b_register wordphrase_b difficulty Answer  \
# 0           גיל           Mood         neutral         שמחה       easy    yes
# 1           גיל           Mood         neutral         שמחה       easy    yes
# 2          סופר       Shopping          formal        מרכול       easy    yes
# 3          סופר       Shopping          formal        מרכול       easy    yes
# 4          עודף        Finance          formal      כסף קטן       hard    yes
# 5          עודף        Finance          formal      כסף קטן       hard    yes
# 6         אבטיח           Food         neutral         מלון       easy     no
# 7         אבטיח           Food         neutral         מלון       easy     no
# 8     רב-מלצרים     Restaurant         neutral       מלצרית       hard     no
# 9     רב-מלצרים     Restaurant         neutral       מלצרית       hard     no
# 10         בוהן     Body parts         neutral        אגודל     medium     no
# 11         בוהן     Body parts         neutral        אגודל     medium     no
# 12         מלאך     Literature          formal          שרף       hard    yes
# 13         מלאך     Literature          formal          שרף       hard    yes
# 14        הברזה      Locations         neutral       ברזייה     medium     no
# 15        הברזה      Locations         neutral       ברזייה     medium     no
# 16      ספונג׳ה        Hygiene         neutral       ניקיון       easy    yes
# 17      ספונג׳ה        Hygiene         neutral       ניקיון       easy    yes
# 18          קרן        Physics         neutral          אור     medium     no
# 19          קרן        Physics         neutral          אור     medium     no
# 20         לורד     Appliances         neutral          טוש     medium    yes
# 21         לורד     Appliances         neutral          טוש     medium    yes
# 22        אבנית       Textiles          formal        פרווה     medium     no
# 23        אבנית       Textiles          formal        פרווה     medium     no
# 24        כבודה        General       technical         מטען       hard    yes
# 25        כבודה        General       technical         מטען       hard    yes
# 26    מסמר שיער      Emotional         neutral        מחריד     medium    yes
# 27    מסמר שיער      Emotional         neutral        מחריד     medium    yes
# 28         מהמם      Emotional         neutral         מרגש       easy     no
# 29         מהמם      Emotional         neutral         מרגש       easy     no
# 30        תיכון        General         neutral         אמצע       hard    yes
# 31        תיכון        General         neutral         אמצע       hard    yes
# 32         סוגה  Entertainment  slang/informal        ז׳אנר       hard    yes
# 33         סוגה  Entertainment  slang/informal        ז׳אנר       hard    yes
# 34         מפתח    Accessories         neutral    מפתח שבדי     medium     no
# 35         מפתח    Accessories         neutral    מפתח שבדי     medium     no
# 36          שוק    Linguistics       technical       שם עצם     medium     no
# 37          שוק    Linguistics       technical       שם עצם     medium     no
# 38           פה       Location         neutral           שם       easy     no
# 39           פה       Location         neutral           שם       easy     no
#
#     Score  Count_of_Test_Takers  Total_Test_Takers
# 0       0                    35                 73
# 1       1                    38                 73
# 2       0                     7                 73
# 3       1                    66                 73
# 4       0                    19                 73
# 5       1                    54                 73
# 6       0                     2                 73
# 7       1                    71                 73
# 8       0                    15                 73
# 9       1                    58                 73
# 10      0                    24                 73
# 11      1                    49                 73
# 12      0                    25                 73
# 13      1                    48                 73
# 14      0                     1                 73
# 15      1                    72                 73
# 16      0                    27                 73
# 17      1                    46                 73
# 18      0                    22                 73
# 19      1                    51                 73
# 20      0                    13                 73
# 21      1                    60                 73
# 22      0                     4                 73
# 23      1                    69                 73
# 24      0                    11                 73
# 25      1                    62                 73
# 26      0                    20                 73
# 27      1                    53                 73
# 28      0                    43                 73
# 29      1                    30                 73
# 30      0                    21                 73
# 31      1                    52                 73
# 32      0                     9                 73
# 33      1                    64                 73
# 34      0                    13                 73
# 35      1                    60                 73
# 36      0                     3                 73
# 37      1                    70                 73
# 38      0                     4                 73
# 39      1                    69                 73

# %% [markdown]
# #### Run all

# %%
# def main():

#     file_initials = ['RC', 'Vocab_1', 'Vocab_2']

#     df_summary = obtain_file_summary_df(file_initials)
#     df_data = obtain_file_data_df(file_initials)
#     raters =  obtain_distinct_raters(df_summary)
#     rc, v1, v2 = merge_raters_to_df_data(df_data, raters)
    
#     return rc, v1, v2

# if __name__ == "__main__":

#     rc, v1, v2 = main()
#     print('Automated data processing completed.')

# %% [markdown]
# # OTHER

# %%
def v1_actual_correct_by_question(v1R):
    
    v1R_temp = v1R[['Language', 'Market', '_worker_id', '_unit_id', 'question_', 'a_domain', 'a_register', 
                    'wordphrase_a', 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score']]
    
    
    v1R_grouped = v1R_temp.groupby(['Language', 'Market', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
                                 'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score'])['_worker_id'].count().reset_index()
    
#     num_test_takers = v1R_temp.groupby(['Language', 'Market', '_unit_id', 'question_', 'a_domain', 'a_register', 'wordphrase_a', 
#                                  'b_domain', 'b_register', 'wordphrase_b', 'difficulty', 'Answer', 'Score'])['_worker_id'].transform('count')
    
    v1R_grouped = v1R_grouped.rename(columns = {"_worker_id" : "Count_of_Test_Takers"})
#     v1R_out = pd.merge(v1R_temp, v1R_grouped[["Count_of_Test_Takers"]], how = 'left', on = '_worker_id')
    
    #v1R_temp['Count_of_Test_Takers'] = num_test_takers
    
    return v1R_grouped

v1R_grouped = v1_actual_correct_by_question(v1R)
v1R_grouped
